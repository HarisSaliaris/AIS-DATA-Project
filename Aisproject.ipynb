# %% [markdown]
# Datasets from (Link): https://zenodo.org/record/1167595 were used in order to study the speed of the vessels, in addition to the weather conditions of each time period. More specifically, the location for the vessels is known on each time period, so the closest weather station can be found, that will provide us with the weather condition present each time period for each vessel. Also a DecisionTreeRegressor prediction algorithm is used in order to predict the beaufort at a certain time.

# %%
import pandas as pd
import numpy as np
import math
import time
import pyspark

# %%
df_1 = pd.read_csv('C:/Users/haris/Desktop/erg/nari_dynamic.csv')

# %%
df_1.head()
# Out:
#    sourcemmsi  navigationalstatus  rateofturn  speedoverground  \
# 0   245257000                 0.0         0.0              0.1
# 1   227705102                15.0      -127.0              0.0
# 2   228131600                15.0      -127.0              8.5
# 3   228051000                 0.0      -127.0              0.0
# 4   227574020                15.0      -127.0              0.1
#
#    courseoverground  trueheading       lon        lat           t
# 0              13.1           36 -4.465718  48.382490  1443650402
# 1             262.7          511 -4.496571  48.382420  1443650403
# 2             263.7          511 -4.644325  48.092247  1443650404
# 3             295.0          511 -4.485108  48.381320  1443650405
# 4             248.6          511 -4.495441  48.383660  1443650406

# %%
df_2 = pd.read_csv('C:/Users/haris/Desktop/erg/table_wheatherObservation.csv')

# %%
df_2.head()
# Out:
#    id_station  local_time    T       Tn       Tx      P   U  id_windDirection  \
# 0        3803  1459551600  9.5 -65536.0 -65536.0  758.1  97                 9
# 1        3803  1459548000  9.4 -65536.0 -65536.0  758.2  96                 9
# 2        3803  1459544400  9.8 -65536.0 -65536.0  758.2  94                 9
# 3        3803  1459540800  9.7 -65536.0 -65536.0  758.4  94                 9
# 4        3803  1459537200  9.9 -65536.0     10.9  758.6  92                 9
#
#    Ff   ff10  ff3   VV   Td      RRR     tR
# 0  15 -65536   20  6.0  9.0 -65536.0 -65536
# 1  15 -65536   20  5.0  8.8 -65536.0 -65536
# 2  16 -65536   20  8.0  8.8 -65536.0 -65536
# 3  15 -65536   19  6.0  8.8 -65536.0 -65536
# 4  15 -65536   20  7.0  8.6      0.2     12

# %%
df_3 = pd.read_csv('C:/Users/haris/Desktop/erg/table_weatherStation.csv')

# %%
df_3.head()
# Out:
#    id_station   station_name  latitude  longitude  elevation
# 0        7107      BRIGNOGAN  48.68330   -4.03330         20
# 1        7100       OUESSANT  48.47330   -5.05690         68
# 2        7117  PERROS GUIREC  48.82580   -3.47295         48
# 3        7207      BELLE ILE  47.30000   -3.21670         37
# 4        7120   SAINT BRIEUX  48.53333   -2.08330        138

# %%
df_1.drop(['navigationalstatus','rateofturn','courseoverground','trueheading'],axis = 1, inplace=True)

# %%
df_1.head()
# Out:
#    sourcemmsi  speedoverground       lon        lat           t
# 0   245257000              0.1 -4.465718  48.382490  1443650402
# 1   227705102              0.0 -4.496571  48.382420  1443650403
# 2   228131600              8.5 -4.644325  48.092247  1443650404
# 3   228051000              0.0 -4.485108  48.381320  1443650405
# 4   227574020              0.1 -4.495441  48.383660  1443650406

# %%
weather_data = pd.merge(df_2,df_3, on = 'id_station', how='outer')

# %%
weather_data.head()
# Out:
#    id_station  local_time    T       Tn       Tx      P   U  id_windDirection  \
# 0        3803  1459551600  9.5 -65536.0 -65536.0  758.1  97                 9
# 1        3803  1459548000  9.4 -65536.0 -65536.0  758.2  96                 9
# 2        3803  1459544400  9.8 -65536.0 -65536.0  758.2  94                 9
# 3        3803  1459540800  9.7 -65536.0 -65536.0  758.4  94                 9
# 4        3803  1459537200  9.9 -65536.0     10.9  758.6  92                 9
#
#    Ff   ff10  ff3   VV   Td      RRR     tR     station_name  latitude  \
# 0  15 -65536   20  6.0  9.0 -65536.0 -65536  ISLES OF SCILLY   49.9167
# 1  15 -65536   20  5.0  8.8 -65536.0 -65536  ISLES OF SCILLY   49.9167
# 2  16 -65536   20  8.0  8.8 -65536.0 -65536  ISLES OF SCILLY   49.9167
# 3  15 -65536   19  6.0  8.8 -65536.0 -65536  ISLES OF SCILLY   49.9167
# 4  15 -65536   20  7.0  8.6      0.2     12  ISLES OF SCILLY   49.9167
#
#    longitude  elevation
# 0       -6.3         31
# 1       -6.3         31
# 2       -6.3         31
# 3       -6.3         31
# 4       -6.3         31

# %%
weather_data.drop(['T','Tn','Tx','P','U','id_windDirection','ff10','ff3','VV','Td','RRR','tR','elevation'],axis = 1, inplace=True)

# %%
weather_data.head()
# Out:
#    id_station  local_time  Ff     station_name  latitude  longitude
# 0        3803  1459551600  15  ISLES OF SCILLY   49.9167       -6.3
# 1        3803  1459548000  15  ISLES OF SCILLY   49.9167       -6.3
# 2        3803  1459544400  16  ISLES OF SCILLY   49.9167       -6.3
# 3        3803  1459540800  15  ISLES OF SCILLY   49.9167       -6.3
# 4        3803  1459537200  15  ISLES OF SCILLY   49.9167       -6.3

# %%
def calculateDistance(x1,y1,x2,y2):  
    dist = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)  
    return dist

# %%
def wind_bft(ms):
    if (0<= ms and ms<=0.2):
        ms=0
        return(ms)
    elif (0.3<=ms and ms<=1.5):
        ms=1
        return(ms)
    elif (1.6<=ms and ms<=3.3):
        ms=2
        return(ms)
    elif (3.4<=ms and ms<=5.4):
        ms=3
        return(ms)
    elif (5.5<=ms and ms<=7.9):
        ms=4
        return(ms)
    elif (8.0<=ms and ms<=10.7):
        ms=5
        return(ms)
    elif (10.8<=ms and ms<=13.8):
        ms=6
        return(ms)
    elif (13.9<=ms and ms<=17.1):
        ms=7
        return(ms)
    elif (17.2<=ms and ms<=20.7):
        ms=8
        return(ms)
    elif (20.8<=ms and ms<=24.4):
        ms=9
        return(ms)
    elif (24.5<=ms and ms<=28.4):
        ms=10
        return(ms)
    elif (28.5<=ms and ms<=32.6):
        ms=11
        return(ms)
    elif (32.7<=ms):
        ms=12
        return(ms)

# %%
a = df_1['t'].unique().tolist()
b = weather_data['local_time'].unique().tolist()

# %%
c = list(set(b) & set(a))

# %%
c
# Out:
# [1457971200,
#  1456128000,
#  1450598400,
#  1452441600,
#  1454284800,
#  1448755200,
#  1446912000,
#  1459011600,
#  1457168400,
#  1451638800,
#  1449795600,
#  1447952400,
#  1446109200,
#  1444266000,
#  1458208800,
#  1454522400,
#  1452679200,
#  1450836000,
#  1448992800,
#  1447149600,
#  1459249200,
#  1457406000,
#  1455562800,
#  1453719600,
#  1450033200,
#  1458446400,
#  1454760000,
#  1449230400,
#  1447387200,
#  1445544000,
#  1443700800,
#  1457643600,
#  1455800400,
#  1450270800,
#  1448427600,
#  1446584400,
#  1456840800,
#  1453154400,
#  1451311200,
#  1445781600,
#  1443938400,
#  1457881200,
#  1456038000,
#  1454194800,
#  1448665200,
#  1446822000,
#  1444978800,
#  1458921600,
#  1455235200,
#  1453392000,
#  1447862400,
#  1446019200,
#  1444176000,
#  1458118800,
#  1456275600,
#  1454432400,
#  1448902800,
#  1447059600,
#  1457316000,
#  1455472800,
#  1453629600,
#  1446256800,
#  1454670000,
#  1452826800,
#  1449140400,
#  1447297200,
#  1445454000,
#  1455710400,
#  1453867200,
#  1450180800,
#  1448337600,
#  1451221200,
#  1449378000,
#  1447534800,
#  1445691600,
#  1443848400,
#  1458594000,
#  1456750800,
#  1454907600,
#  1457791200,
#  1455948000,
#  1452261600,
#  1450418400,
#  1448575200,
#  1446732000,
#  1458831600,
#  1456988400,
#  1453302000,
#  1451458800,
#  1447772400,
#  1445929200,
#  1456185600,
#  1454342400,
#  1459069200,
#  1457226000,
#  1455382800,
#  1449853200,
#  1448010000,
#  1446166800,
#  1444323600,
#  1458266400,
#  1456423200,
#  1454580000,
#  1452736800,
#  1450893600,
#  1449050400,
#  1447207200,
#  1459306800,
#  1457463600,
#  1455620400,
#  1450090800,
#  1448247600,
#  1444561200,
#  1458504000,
#  1456660800,
#  1454817600,
#  1451131200,
#  1449288000,
#  1447444800,
#  1445601600,
#  1443758400,
#  1457701200,
#  1454014800,
#  1452171600,
#  1458741600,
#  1456898400,
#  1447682400,
#  1445839200,
#  1443996000,
#  1457938800,
#  1456095600,
#  1450566000,
#  1448722800,
#  1458979200,
#  1457136000,
#  1455292800,
#  1453449600,
#  1451606400,
#  1449763200,
#  1447920000,
#  1444233600,
#  1458176400,
#  1456333200,
#  1454490000,
#  1450803600,
#  1448960400,
#  1457373600,
#  1455530400,
#  1453687200,
#  1451844000,
#  1448157600,
#  1446314400,
#  1458414000,
#  1454727600,
#  1452884400,
#  1449198000,
#  1459454400,
#  1457611200,
#  1452081600,
#  1444708800,
#  1453924800,
#  1458651600,
#  1454965200,
#  1453122000,
#  1451278800,
#  1449435600,
#  1447592400,
#  1457848800,
#  1456005600,
#  1454162400,
#  1448632800,
#  1458889200,
#  1455202800,
#  1453359600,
#  1451516400,
#  1449673200,
#  1447830000,
#  1444143600,
#  1458086400,
#  1456243200,
#  1454400000,
#  1452556800,
#  1448870400,
#  1445184000,
#  1450713600,
#  1447027200,
#  1459126800,
#  1455440400,
#  1451754000,
#  1444381200,
#  1457283600,
#  1453597200,
#  1449910800,
#  1446224400,
#  1456480800,
#  1454637600,
#  1452794400,
#  1449108000,
#  1445421600,
#  1448305200,
#  1444618800,
#  1457521200,
#  1455678000,
#  1453834800,
#  1451991600,
#  1450148400,
#  1446462000,
#  1454875200,
#  1453032000,
#  1449345600,
#  1443816000,
#  1455915600,
#  1454072400,
#  1452229200,
#  1450386000,
#  1448542800,
#  1458799200,
#  1456956000,
#  1453269600,
#  1449583200,
#  1455112800,
#  1444053600,
#  1457996400,
#  1456153200,
#  1454310000,
#  1450623600,
#  1448780400,
#  1459036800,
#  1457193600,
#  1455350400,
#  1451664000,
#  1449820800,
#  1447977600,
#  1458234000,
#  1456390800,
#  1452704400,
#  1450861200,
#  1449018000,
#  1445331600,
#  1447174800,
#  1459274400,
#  1455588000,
#  1453744800,
#  1451901600,
#  1446372000,
#  1458471600,
#  1454785200,
#  1452942000,
#  1449255600,
#  1447412400,
#  1443726000,
#  1457668800,
#  1455825600,
#  1453982400,
#  1452139200,
#  1446609600,
#  1449493200,
#  1458709200,
#  1456866000,
#  1455022800,
#  1451336400,
#  1448690400,
#  1445004000,
#  1457906400,
#  1452376800,
#  1450533600,
#  1446847200,
#  1455260400,
#  1451574000,
#  1447887600,
#  1444201200,
#  1458946800,
#  1457103600,
#  1453417200,
#  1458144000,
#  1456300800,
#  1454457600,
#  1450771200,
#  1448928000,
#  1447084800,
#  1455498000,
#  1451811600,
#  1444438800,
#  1457341200,
#  1453654800,
#  1447322400,
#  1458381600,
#  1452852000,
#  1449165600,
#  1445479200,
#  1444676400,
#  1446519600,
#  1459422000,
#  1457578800,
#  1453892400,
#  1450206000,
#  1451246400,
#  1447560000,
#  1443873600,
#  1454932800,
#  1449403200,
#  1457816400,
#  1455973200,
#  1454130000,
#  1450443600,
#  1448600400,
#  1446757200,
#  1444914000,
#  1444111200,
#  1447797600,
#  1451484000,
#  1457013600,
#  1453327200,
#  1449640800,
#  1445954400,
#  1458856800,
#  1448838000,
#  1445151600,
#  1458054000,
#  1456210800,
#  1454367600,
#  1452524400,
#  1457251200,
#  1453564800,
#  1446192000,
#  1459094400,
#  1455408000,
#  1451721600,
#  1444348800,
#  1458291600,
#  1454605200,
#  1452762000,
#  1450918800,
#  1450116000,
#  1446429600,
#  1451959200,
#  1448272800,
#  1459332000,
#  1457488800,
#  1455645600,
#  1453802400,
#  1454842800,
#  1456686000,
#  1451156400,
#  1449313200,
#  1443783600,
#  1455883200,
#  1454040000,
#  1450353600,
#  1448510400,
#  1444824000,
#  1458766800,
#  1456923600,
#  1449550800,
#  1445864400,
#  1444021200,
#  1456120800,
#  1452434400,
#  1450591200,
#  1448748000,
#  1445061600,
#  1457161200,
#  1455318000,
#  1453474800,
#  1451631600,
#  1447945200,
#  1458201600,
#  1456358400,
#  1454515200,
#  1452672000,
#  1450828800,
#  1448985600,
#  1447142400,
#  1445299200,
#  1459242000,
#  1455555600,
#  1453712400,
#  1448182800,
#  1454752800,
#  1456596000,
#  1449223200,
#  1447380000,
#  1457636400,
#  1455793200,
#  1453950000,
#  1452106800,
#  1450263600,
#  1446577200,
#  1444734000,
#  1458676800,
#  1456833600,
#  1454990400,
#  1453147200,
#  1451304000,
#  1445774400,
#  1457874000,
#  1456030800,
#  1450501200,
#  1448658000,
#  1444971600,
#  1458914400,
#  1457071200,
#  1455228000,
#  1451541600,
#  1446012000,
#  1444168800,
#  1458111600,
#  1456268400,
#  1454425200,
#  1452582000,
#  1448895600,
#  1445209200,
#  1459152000,
#  1457308800,
#  1453622400,
#  1448092800,
#  1446249600,
#  1454662800,
#  1452819600,
#  1445446800,
#  1457546400,
#  1455703200,
#  1453860000,
#  1452016800,
#  1450173600,
#  1448330400,
#  1446487200,
#  1444644000,
#  1458586800,
#  1447527600,
#  1443841200,
#  1457784000,
#  1455940800,
#  1454097600,
#  1450411200,
#  1448568000,
#  1446724800,
#  1458824400,
#  1456981200,
#  1455138000,
#  1453294800,
#  1451451600,
#  1449608400,
#  1447765200,
#  1458021600,
#  1456178400,
#  1454335200,
#  1445119200,
#  1459062000,
#  1457218800,
#  1455375600,
#  1448002800,
#  1446159600,
#  1444316400,
#  1458259200,
#  1456416000,
#  1449043200,
#  1457456400,
#  1455613200,
#  1450083600,
#  1444554000,
#  1458496800,
#  1456653600,
#  1454810400,
#  1447437600,
#  1457694000,
#  1455850800,
#  1454007600,
#  1452164400,
#  1450321200,
#  1448478000,
#  1446634800,
#  1458734400,
#  1455048000,
#  1453204800,
#  1451361600,
#  1445832000,
#  1457931600,
#  1456088400,
#  1452402000,
#  1450558800,
#  1448715600,
#  1446872400,
#  1458972000,
#  1457128800,
#  1455285600,
#  1453442400,
#  1451599200,
#  1449756000,
#  1447912800,
#  1444226400,
#  1456326000,
#  1454482800,
#  1452639600,
#  1450796400,
#  1448953200,
#  1447110000,
#  1459209600,
#  1457366400,
#  1455523200,
#  1453680000,
#  1449993600,
#  1448150400,
#  1444464000,
#  1458406800,
#  1456563600,
#  1454720400,
#  1452877200,
#  1451034000,
#  1447347600,
#  1445504400,
#  1457604000,
#  1455760800,
#  1453917600,
#  1452074400,
#  1448388000,
#  1458644400,
#  1454958000,
#  1451271600,
#  1449428400,
#  1447585200,
#  1445742000,
#  1443898800,
#  1457841600,
#  1454155200,
#  1448625600,
#  1446782400,
#  1444939200,
#  1458882000,
#  1453352400,
#  1451509200,
#  1449666000,
#  1458079200,
#  1456236000,
#  1454392800,
#  1452549600,
#  1450706400,
#  1459119600,
#  1457276400,
#  1453590000,
#  1449903600,
#  1446217200,
#  1454630400,
#  1458316800,
#  1456473600,
#  1452787200,
#  1449100800,
#  1457514000,
#  1455670800,
#  1453827600,
#  1450141200,
#  1448298000,
#  1446454800,
#  1454868000,
#  1458554400,
#  1456711200,
#  1453024800,
#  1451181600,
#  1445652000,
#  1443808800,
#  1450378800,
#  1448535600,
#  1458792000,
#  1455105600,
#  1447732800,
#  1445889600,
#  1444046400,
#  1457989200,
#  1456146000,
#  1454302800,
#  1452459600,
#  1450616400,
#  1457186400,
#  1453500000,
#  1451656800,
#  1449813600,
#  1447970400,
#  1444284000,
#  1458226800,
#  1456383600,
#  1452697200,
#  1450854000,
#  1449010800,
#  1447167600,
#  1445324400,
#  1459267200,
#  1455580800,
#  1453737600,
#  1446364800,
#  1444521600,
#  1454778000,
#  1449248400,
#  1447405200,
#  1457661600,
#  1455818400,
#  1452132000,
#  1450288800,
#  1448445600,
#  1446602400,
#  1458702000,
#  1453172400,
#  1451329200,
#  1449486000,
#  1447642800,
#  1445799600,
#  1457899200,
#  1456056000,
#  1450526400,
#  1448683200,
#  1444996800,
#  1458939600,
#  1457096400,
#  1455253200,
#  1453410000,
#  1451566800,
#  1444194000,
#  1458136800,
#  1456293600,
#  1454450400,
#  1450764000,
#  1445234400,
#  1453647600,
#  1451804400,
#  1454688000,
#  1458374400,
#  1456531200,
#  1451001600,
#  1449158400,
#  1459414800,
#  1455728400,
#  1453885200,
#  1452042000,
#  1450198800,
#  1448355600,
#  1446512400,
#  1444669200,
#  1454925600,
#  1458612000,
#  1456768800,
#  1453082400,
#  1451239200,
#  1449396000,
#  1455966000,
#  1450436400,
#  1444906800,
#  1458849600,
#  1457006400,
#  1453320000,
#  1451476800,
#  1447790400,
#  1444104000,
#  1458046800,
#  1456203600,
#  1454360400,
#  1452517200,
#  1450674000,
#  1448830800,
#  1446987600,
#  1445144400,
#  1459087200,
#  1457244000,
#  1455400800,
#  1453557600,
#  1451714400,
#  1449871200,
#  1448028000,
#  1458284400,
#  1456441200,
#  1454598000,
#  1449068400,
#  1445382000,
#  1459324800,
#  1455638400,
#  1453795200,
#  1450108800,
#  1448265600,
#  1444579200,
#  1458522000,
#  1456678800,
#  1454835600,
#  1449306000,
#  1445619600,
#  1443776400,
#  1455876000,
#  1454032800,
#  1452189600,
#  1444816800,
#  1458759600,
#  1456916400,
#  1453230000,
#  1449543600,
#  1445857200,
#  1457956800,
#  1456113600,
#  1454270400,
#  1452427200,
#  1450584000,
#  1448740800,
#  1446897600,
#  1445054400,
#  1458997200,
#  1457154000,
#  1455310800,
#  1451624400,
#  1447938000,
#  1456351200,
#  1454508000,
#  1452664800,
#  1450821600,
#  1448978400,
#  1459234800,
#  1455548400,
#  1453705200,
#  1448175600,
#  1454745600,
#  1452902400,
#  1451059200,
#  1447372800,
#  1449216000,
#  1443686400,
#  1457629200,
#  1455786000,
#  1453942800,
#  1448413200,
#  1450256400,
#  1444726800,
#  1456826400,
#  1453140000,
#  1451296800,
#  1445767200,
#  1443924000,
#  1456023600,
#  1452337200,
#  1450494000,
#  1448650800,
#  1446807600,
#  1444964400,
#  1458907200,
#  1457064000,
#  1455220800,
#  1453377600,
#  1444161600,
#  1447848000,
#  1449691200,
#  1451534400,
#  1458104400,
#  1456261200,
#  1452574800,
#  1450731600,
#  1448888400,
#  1447045200,
#  1459144800,
#  1453615200,
#  1451772000,
#  1448085600,
#  1444399200,
#  1458342000,
#  1456498800,
#  1454655600,
#  1452812400,
#  1449126000,
#  1450969200,
#  1457539200,
#  1455696000,
#  1450166400,
#  1448323200,
#  1444636800,
#  1446480000,
#  1458579600,
#  1456736400,
#  1454893200,
#  1451206800,
#  1447520400,
#  1449363600,
#  1457776800,
#  1455933600,
#  1454090400,
#  1452247200,
#  1448560800,
#  1446717600,
#  1444874400,
#  1458817200,
#  1455130800,
#  1453287600,
#  1451444400,
#  1449601200,
#  1444071600,
#  1447758000,
#  1454328000,
#  1452484800,
#  1450641600,
#  1448798400,
#  1445112000,
#  1446152400,
#  1459054800,
#  1457211600,
#  1447995600,
#  1449838800,
#  1451682000,
#  1453525200,
#  1455368400,
#  1444309200,
#  1449036000,
#  1458252000,
#  1456408800,
#  1454565600,
#  1450879200,
#  1445349600,
#  1455606000,
#  1453762800,
#  1450076400,
#  1448233200,
#  1446390000,
#  1456646400,
#  1449273600,
#  1447430400,
#  1445587200,
#  1443744000,
#  1457686800,
#  1455843600,
#  1454000400,
#  1446627600,
#  1448470800,
#  1450314000,
#  1452157200,
#  1443981600,
#  1458727200,
#  1455040800,
#  1453197600,
#  1445824800,
#  1447668000,
#  1449511200,
#  1445022000,
#  1457924400,
#  1456081200,
#  1452394800,
#  1450551600,
#  1447905600,
#  1458964800,
#  1449748800,
#  1451592000,
#  1453435200,
#  1455278400,
#  1457121600,
#  1444219200,
#  1452632400,
#  1448946000,
#  1447102800,
#  1457359200,
#  1455516000,
#  1449986400,
#  1454713200,
#  1452870000,
#  1449183600,
#  1459440000,
#  1457596800,
#  1446537600,
#  1448380800,
#  1450224000,
#  1452067200,
#  1453910400,
#  1455753600,
#  1445734800,
#  1458637200,
#  1454950800,
#  1453107600,
#  1451264400,
#  1449421200,
#  1455991200,
#  1454148000,
#  1450461600,
#  1446775200,
#  1449658800,
#  1458874800,
#  1457031600,
#  1455188400,
#  1453345200,
#  1451502000,
#  1444129200,
#  1445972400,
#  1447815600,
#  1458072000,
#  1456228800,
#  1452542400,
#  1450699200,
#  1448856000,
#  1459112400,
#  1457269200,
#  1455426000,
#  1453582800,
#  1444366800,
#  1446210000,
#  1448053200,
#  1449896400,
#  1451739600,
#  1458309600,
#  1456466400,
#  1454623200,
#  1450936800,
#  1449093600,
#  1445407200,
#  1459350000,
#  1457506800,
#  1455663600,
#  1451977200,
#  1453820400,
#  1447488000,
#  1458547200,
#  1456704000,
#  1445644800,
#  1453017600,
#  1454860800,
#  1448528400,
#  1455901200,
#  1450371600,
#  1444842000,
#  1458784800,
#  1456941600,
#  1451412000,
#  1449568800,
#  1447725600,
#  1444039200,
#  1452452400,
#  1454295600,
#  1457982000,
#  1456138800,
#  1448766000,
#  1450609200,
#  1457179200,
#  1453492800,
#  1451649600,
#  1447963200,
#  1446120000,
#  1444276800,
#  1445317200,
#  1458219600,
#  1454533200,
#  1452690000,
#  1450846800,
#  1447160400,
#  1449003600,
#  1448200800,
#  1459260000,
#  1457416800,
#  1455573600,
#  1453730400,
#  1451887200,
#  1447398000,
#  1458457200,
#  1454770800,
#  1452927600,
#  1449241200,
#  1445554800,
#  1455811200,
#  1453968000,
#  1452124800,
#  1446595200,
#  1448438400,
#  1456851600,
#  1451322000,
#  1443949200,
#  1458694800,
#  1445792400,
#  1449478800,
#  1457892000,
#  1456048800,
#  1450519200,
#  1448676000,
#  1446832800,
#  1444989600,
#  1458932400,
#  1455246000,
#  1453402800,
#  1451559600,
#  1446030000,
#  1447873200,
#  1449716400,
#  1447070400,
#  1458129600,
#  1456286400,
#  1454443200,
#  1448913600,
#  1446267600,
#  1448110800,
#  1459170000,
#  1457326800,
#  1455483600,
#  1453640400,
#  1451797200,
#  1449151200,
#  1450994400,
#  1458367200,
#  1456524000,
#  1452837600,
#  1447308000,
#  1457564400,
#  1455721200,
#  1450191600,
#  1448348400,
#  1454918400,
#  ...]

# %%
#grhgoros tropos 20 lepta
start_time=time.time()
k={}
for i in c:
    df_ships = df_1.loc[df_1['t']==i]
    df_weather = weather_data.loc[weather_data['local_time']==i]
    df_ships['station_name'] = 0
    df_ships['Ff'] = 0
    ship_coor = df_ships[['lon','lat']].values
    weather_coor = df_weather[['longitude','latitude']].values
    dist_matrix = np.linalg.norm(ship_coor[:, np.newaxis] - weather_coor, axis = 2)
    for row in range(len(dist_matrix)):
        mini = np.argmin(dist_matrix[row])
        df_ships.iloc[row,-2]=df_weather.iloc[mini]['station_name']
        df_ships.iloc[row,-1]=wind_bft(df_weather.iloc[mini]['Ff'])
    k[i]=df_ships
print(time.time()-start_time)
# Out:
# C:\Users\haris\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\haris\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\haris\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 86.06441688537598

# %%
final_data=[]
for i in k.values():
    print(i)
    final_data.append(i)
# Out:
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13602158   227592820             16.9 -4.483425  48.350903  1457971200
# 13602159   228762000              0.2 -4.506792  48.374588  1457971200
#
#          station_name  Ff
# 13602158    BRIGNOGAN   7
# 13602159     OUESSANT   6
#           sourcemmsi  speedoverground       lon       lat           t  \
# 11624163   226178000              0.0 -4.325843  48.09822  1456128000
#
#          station_name  Ff
# 11624163    BRIGNOGAN   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 6457456    228051000              0.0 -4.485086  48.381320  1450598400
# 6457457    227580520              0.0 -4.497093  48.379566  1450598400
# 16195655   226318000             19.6 -4.759283  48.212704  1450598400
#
#          station_name  Ff
# 6457456     BRIGNOGAN   3
# 6457457     BRIGNOGAN   3
# 16195655     OUESSANT   5
#           sourcemmsi  speedoverground       lon      lat           t  \
# 16625356   356071000              0.2 -4.322504  48.1183  1452441600
#
#          station_name  Ff
# 16625356    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 9746215   228394000              2.1 -4.911723  48.104588  1454284800
#
#         station_name  Ff
# 9746215     OUESSANT   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 15793077   228064900              0.0 -4.511863  48.364685  1448755200
#
#          station_name  Ff
# 15793077     OUESSANT   7
#          sourcemmsi  speedoverground       lon        lat           t  \
# 3103043   228186700              0.0 -4.512832  48.370667  1446912000
#
#         station_name  Ff
# 3103043     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14523572   228186700            102.3 -4.512567  48.370846  1459011600
# 14523573   234056000              0.0 -4.518463  48.367275  1459011600
#
#          station_name  Ff
# 14523572     OUESSANT   6
# 14523573     OUESSANT   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12923882   227009310              3.8 -4.584937  48.281220  1457168400
# 12923883   228186700            102.3 -4.512665  48.370834  1457168400
# 12923884   228762000              0.0 -4.506763  48.374615  1457168400
# 17688686   227003050             16.8 -4.805705  48.369408  1457168400
#
#          station_name  Ff
# 12923882     OUESSANT   7
# 12923883     OUESSANT   7
# 12923884     OUESSANT   7
# 17688686     OUESSANT   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 7092208    227574020              0.0 -4.495359  48.383667  1451638800
# 7092209    228051000              0.0 -4.484573  48.381120  1451638800
# 16409851   220540000              0.3 -4.330435  48.118507  1451638800
#
#          station_name  Ff
# 7092208     BRIGNOGAN   5
# 7092209     BRIGNOGAN   5
# 16409851    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5851329   227904000             10.2 -4.508598  48.360374  1449795600
#
#         station_name  Ff
# 5851329     OUESSANT   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 4072100   226263000              0.1 -4.485738  48.379820  1447952400
# 4072101   227574020              0.0 -4.495303  48.383602  1447952400
#
#         station_name  Ff
# 4072100    BRIGNOGAN   6
# 4072101    BRIGNOGAN   6
#           sourcemmsi  speedoverground     lon       lat           t  \
# 15268118   228041600              0.0 -4.4733  48.38238  1446109200
#
#          station_name  Ff
# 15268118    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14992426   227306100              0.2 -4.588417  48.279858  1444266000
#
#          station_name  Ff
# 14992426     OUESSANT   2
#           sourcemmsi  speedoverground       lon       lat           t  \
# 13832785   227574020              0.1 -4.495438  48.38362  1458208800
#
#          station_name  Ff
# 13832785    BRIGNOGAN   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 9998938   227319570              8.0 -4.658703  48.168045  1454522400
#
#         station_name  Ff
# 9998938     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 16678296   226263000              0.0 -4.485752  48.379852  1452679200
#
#          station_name  Ff
# 16678296    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 6619362   228793000              0.0 -4.516768  48.36886  1450836000
# 6619363   228051000              0.0 -4.485070  48.38132  1450836000
#
#         station_name  Ff
# 6619362     OUESSANT   6
# 6619363    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 5158695    228336000              9.1 -4.864073  48.411053  1448992800
# 5158696    227999400              0.0 -4.520709  48.328613  1448992800
# 5158697    227705102             16.6 -4.489113  48.369175  1448992800
# 5158698    227574020              0.0 -4.497004  48.382233  1448992800
# 15836123   227142200              0.4 -4.576018  48.139620  1448992800
#
#          station_name  Ff
# 5158695      OUESSANT   4
# 5158696      OUESSANT   4
# 5158697     BRIGNOGAN   3
# 5158698     BRIGNOGAN   3
# 15836123     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 18313255   228155700              9.6 -4.486333  48.298286  1447149600
#
#          station_name  Ff
# 18313255    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14673480   227705102             19.3 -4.456171  48.301014  1459249200
# 18029154   249297000              0.0 -4.454640  48.383015  1459249200
#
#          station_name  Ff
# 14673480    BRIGNOGAN   4
# 18029154    BRIGNOGAN   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13124553   228762000              0.0 -4.506767  48.374622  1457406000
#
#          station_name  Ff
# 13124553     OUESSANT   3
#           sourcemmsi  speedoverground       lon       lat           t  \
# 11008072   228109000              2.1 -4.957678  48.19394  1455562800
#
#          station_name  Ff
# 11008072     OUESSANT   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 9128453   228186700            102.3 -4.512498  48.370834  1453719600
#
#         station_name  Ff
# 9128453     OUESSANT   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6000990   314255000              9.4 -4.969665  47.853333  1450033200
#
#         station_name  Ff
# 6000990     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14006563   227003050              0.0 -4.485743  48.381092  1458446400
#
#          station_name  Ff
# 14006563    BRIGNOGAN   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10287324   234056000              0.0 -4.518493  48.367325  1454760000
#
#          station_name  Ff
# 10287324     OUESSANT   9
#           sourcemmsi  speedoverground       lon        lat           t  \
# 5381644    228051000              0.0 -4.485082  48.381348  1449230400
# 5381645    227580520              0.0 -4.497063  48.379555  1449230400
# 5381646    227574020              0.0 -4.497046  48.382180  1449230400
# 18453812   228796000              2.0 -4.460837  48.310600  1449230400
#
#          station_name  Ff
# 5381644     BRIGNOGAN   3
# 5381645     BRIGNOGAN   3
# 5381646     BRIGNOGAN   3
# 18453812    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 18329998   227362110              0.0 -4.489958  48.379257  1447387200
#
#          station_name  Ff
# 18329998    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon       lat           t  \
# 1832540    227005550              0.0 -4.487263  48.38086  1445544000
# 15185329   311166000             17.5 -4.711332  47.84250  1445544000
#
#          station_name  Ff
# 1832540     BRIGNOGAN   3
# 15185329     OUESSANT   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 18086780   228155700              5.5 -4.467277  48.377266  1443700800
#
#          station_name  Ff
# 18086780    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon       lat           t  \
# 13364715   228762000              0.0 -4.506747  48.37459  1457643600
#
#          station_name  Ff
# 13364715     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11319296   227941000              0.0 -4.326561  48.098297  1455800400
# 11319297   227091000              4.9 -4.498815  48.337666  1455800400
#
#          station_name  Ff
# 11319296    BRIGNOGAN   2
# 11319297     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 6180540    227008170             13.1 -4.582648  48.328518  1450270800
# 18547340   227640710              7.9 -4.465463  48.338220  1450270800
#
#          station_name  Ff
# 6180540      OUESSANT   6
# 18547340    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon     lat           t  \
# 4615757   219124000              4.6 -4.463012  48.373  1448427600
#
#         station_name  Ff
# 4615757    BRIGNOGAN   7
#          sourcemmsi  speedoverground       lon       lat           t  \
# 2768039   227580520              0.0 -4.497045  48.37954  1446584400
#
#         station_name  Ff
# 2768039    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12344538   227574020              0.1 -4.496598  48.382385  1456840800
# 12344539   234056000              2.0 -4.495702  48.329240  1456840800
# 12627824   227574020              0.1 -4.496598  48.382385  1456840800
# 12627825   234056000              2.0 -4.495702  48.329240  1456840800
#
#          station_name  Ff
# 12344538    BRIGNOGAN   6
# 12344539     OUESSANT   6
# 12627824    BRIGNOGAN   6
# 12627825     OUESSANT   6
#          sourcemmsi  speedoverground      lon        lat           t  \
# 8299854   228186700            102.3 -4.51303  48.371128  1453154400
#
#         station_name  Ff
# 8299854     OUESSANT   3
#          sourcemmsi  speedoverground       lon       lat           t  \
# 6886940   228051000              0.0 -4.485126  48.38134  1451311200
#
#         station_name  Ff
# 6886940    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 15229390   228017700             15.3 -4.857657  48.381912  1445781600
#
#          station_name  Ff
# 15229390     OUESSANT   5
#         sourcemmsi  speedoverground       lon        lat           t  \
# 253968   227005550             19.4 -4.605230  48.328650  1443938400
# 253969   259019000              0.0 -4.514797  48.369354  1443938400
#
#        station_name  Ff
# 253968     OUESSANT   4
# 253969     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13530954   227574020              0.0 -4.495345  48.383636  1457881200
#
#          station_name  Ff
# 13530954    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon       lat           t  \
# 11528138   227003050              0.0 -4.485902  48.38078  1456038000
#
#          station_name  Ff
# 11528138    BRIGNOGAN   5
#          sourcemmsi  speedoverground      lon      lat           t  \
# 9684637   228032800              9.7 -4.72868  48.1448  1454194800
#
#         station_name  Ff
# 9684637     OUESSANT   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 4856791    228051000              0.1 -4.485082  48.381310  1448665200
# 15778746   304010986              8.5 -5.162098  48.144928  1448665200
#
#          station_name  Ff
# 4856791     BRIGNOGAN   7
# 15778746     OUESSANT   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 3019791    227612860             17.5 -4.489588  48.365173  1446822000
# 15380819   228017700             16.2 -4.853060  48.403000  1446822000
#
#          station_name  Ff
# 3019791     BRIGNOGAN   5
# 15380819     OUESSANT   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 1310591   245181000              0.1 -4.469968  48.380775  1444978800
#
#         station_name  Ff
# 1310591    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14446884   227574020              0.0 -4.496705  48.382427  1458921600
# 17971440   227008170             14.9 -4.550965  48.345318  1458921600
#
#          station_name  Ff
# 14446884    BRIGNOGAN   3
# 17971440     OUESSANT   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10708242   228051000              0.0 -4.485135  48.381336  1455235200
# 17200836   234056000              0.0 -4.518559  48.367226  1455235200
#
#          station_name  Ff
# 10708242    BRIGNOGAN   4
# 17200836     OUESSANT   4
#          sourcemmsi  speedoverground       lon       lat           t  \
# 8662379   227114300              7.8 -4.822370  48.31120  1453392000
# 8662380   227705102             17.4 -4.488133  48.36054  1453392000
#
#         station_name  Ff
# 8662379     OUESSANT   7
# 8662380    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 3937767   228109000              5.1 -4.705157  48.122295  1447862400
#
#         station_name  Ff
# 3937767     OUESSANT   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 2299099   367852000              6.5 -4.488147  48.365704  1446019200
#
#         station_name  Ff
# 2299099    BRIGNOGAN   3
#         sourcemmsi  speedoverground      lon       lat           t  \
# 490139   227143600              0.2 -4.32382  48.09802  1444176000
#
#        station_name  Ff
# 490139    BRIGNOGAN   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 17850062   228041600              0.0 -4.473288  48.382366  1458118800
#
#          station_name  Ff
# 17850062    BRIGNOGAN   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11768134   228186700            102.3 -4.512665  48.370834  1456275600
# 11768135   227148000              6.1 -5.173810  48.122734  1456275600
# 11768136   227003050              0.0 -4.485732  48.381138  1456275600
#
#          station_name  Ff
# 11768134     OUESSANT   6
# 11768135     OUESSANT   6
# 11768136    BRIGNOGAN   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 9892950    228144000              9.3 -4.511390  48.166893  1454432400
# 9892951    228293000              9.3 -4.528248  48.150417  1454432400
# 9892952    314237000              8.7 -4.479385  48.366127  1454432400
# 9892953    228208800              9.2 -4.483338  48.132244  1454432400
# 17029262   234056000              1.6 -4.331052  48.123460  1454432400
#
#          station_name  Ff
# 9892950      OUESSANT   5
# 9892951      OUESSANT   5
# 9892952     BRIGNOGAN   5
# 9892953      OUESSANT   5
# 17029262    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5063233   311009700              1.5 -4.479163  48.381565  1448902800
# 5063234   228051000              0.8 -4.480670  48.381836  1448902800
#
#         station_name  Ff
# 5063233    BRIGNOGAN   5
# 5063234    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 3226147   227941000              7.9 -4.829683  48.059048  1447059600
#
#         station_name  Ff
# 3226147     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13039150   228762000              0.0 -4.506752  48.374607  1457316000
#
#          station_name  Ff
# 13039150     OUESSANT   4
#           sourcemmsi  speedoverground       lon       lat           t  \
# 10903436   227580520              0.0 -4.497015  48.37953  1455472800
#
#          station_name  Ff
# 10903436    BRIGNOGAN   6
#           sourcemmsi  speedoverground       lon       lat           t  \
# 16867311   228064900              0.0 -4.511773  48.36464  1453629600
#
#          station_name  Ff
# 16867311     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 15295225   226263000              0.1 -4.485764  48.379852  1446256800
#
#          station_name  Ff
# 15295225    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon       lat           t  \
# 10185298   227580520              0.0 -4.497028  48.37953  1454670000
# 17106493   226263000              1.5 -4.586348  48.28474  1454670000
#
#          station_name  Ff
# 10185298    BRIGNOGAN   4
# 17106493     OUESSANT   6
#          sourcemmsi  speedoverground       lon      lat           t  \
# 7947226   227008170              0.0 -4.486165  48.3815  1452826800
#
#         station_name  Ff
# 7947226    BRIGNOGAN   8
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5305024   228051000              0.0 -4.485086  48.381330  1449140400
# 5305025   538002973              0.0 -4.471899  48.381466  1449140400
#
#         station_name  Ff
# 5305024    BRIGNOGAN   4
# 5305025    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 3464793   228208700              0.1 -4.324798  48.098114  1447297200
# 3464794   228068600              0.0 -4.482346  48.380913  1447297200
#
#         station_name  Ff
# 3464793    BRIGNOGAN   2
# 3464794    BRIGNOGAN   2
#          sourcemmsi  speedoverground       lon        lat           t  \
# 1732830   227580520              0.0 -4.497008  48.379513  1445454000
# 1732831   228150000              8.4 -4.467425  48.120213  1445454000
#
#         station_name  Ff
# 1732830    BRIGNOGAN   4
# 1732831     OUESSANT   5
#           sourcemmsi  speedoverground       lon       lat           t  \
# 11198361   228109000              1.9 -4.694787  48.12203  1455710400
#
#          station_name  Ff
# 11198361     OUESSANT   6
#          sourcemmsi  speedoverground       lon     lat           t  \
# 9321271   228186700            102.3 -4.586832  48.285  1453867200
#
#         station_name  Ff
# 9321271     OUESSANT   7
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6112162   999999999              0.0 -4.513318  48.369953  1450180800
# 6112163   227574020             18.5 -4.439293  48.302036  1450180800
#
#         station_name  Ff
# 6112162     OUESSANT   7
# 6112163    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 4546515   228051000              0.0 -4.485086  48.38132  1448337600
# 4546516   227091000              0.0 -4.478163  48.38320  1448337600
#
#         station_name  Ff
# 4546515    BRIGNOGAN   3
# 4546516    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6798233   227705102              0.2 -4.495392  48.383743  1451221200
#
#         station_name  Ff
# 6798233    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5489848   538002973              0.0 -4.471882  48.381516  1449378000
#
#         station_name  Ff
# 5489848    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon      lat           t  \
# 3664394   228051000              0.0 -4.485074  48.3813  1447534800
#
#         station_name  Ff
# 3664394    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 1953258    227705102              0.1 -4.496654  48.382454  1445691600
# 18220669   227163870              4.0 -4.471753  48.325222  1445691600
#
#          station_name  Ff
# 1953258     BRIGNOGAN   5
# 18220669    BRIGNOGAN   5
#         sourcemmsi  speedoverground       lon       lat           t  \
# 179376   227705102              0.0 -4.495448  48.38366  1443848400
#
#        station_name  Ff
# 179376    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14146642   249959000              8.7 -4.800357  48.145634  1458594000
#
#          station_name  Ff
# 14146642     OUESSANT   4
#           sourcemmsi  speedoverground       lon      lat           t  \
# 12224691   227941000              0.0 -4.327225  48.1001  1456750800
#
#          station_name  Ff
# 12224691    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10412489   226178000              0.0 -4.323938  48.098026  1454907600
#
#          station_name  Ff
# 10412489    BRIGNOGAN   7
#           sourcemmsi  speedoverground       lon      lat           t  \
# 13477666   228762000              0.1 -4.506752  48.3746  1457791200
#
#          station_name  Ff
# 13477666     OUESSANT   2
#           sourcemmsi  speedoverground       lon       lat           t  \
# 11451568   227941000              0.0 -4.327213  48.10009  1455948000
# 11451569   226178000              0.0 -4.325853  48.09823  1455948000
#
#          station_name  Ff
# 11451568    BRIGNOGAN   5
# 11451569    BRIGNOGAN   5
#          sourcemmsi  speedoverground      lon        lat           t  \
# 7509086   227392000              0.0 -4.32492  48.098125  1452261600
#
#         station_name  Ff
# 7509086    BRIGNOGAN   3
#          sourcemmsi  speedoverground      lon       lat           t  \
# 6316863   999999999              0.0 -4.51334  48.36994  1450418400
#
#         station_name  Ff
# 6316863     OUESSANT   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 4769985   228344800              0.0 -4.478374  48.383114  1448575200
#
#         station_name  Ff
# 4769985    BRIGNOGAN   2
#          sourcemmsi  speedoverground       lon        lat           t  \
# 2923667   227705102              0.0 -4.495430  48.383640  1446732000
# 2923668   228186700              0.0 -4.512832  48.370667  1446732000
#
#         station_name  Ff
# 2923667    BRIGNOGAN   5
# 2923668     OUESSANT   6
#           sourcemmsi  speedoverground      lon        lat           t  \
# 14369606   234056000              3.2 -4.68215  48.286915  1458831600
# 14369607   227574020              0.0 -4.49534  48.383633  1458831600
#
#          station_name  Ff
# 14369606     OUESSANT   5
# 14369607    BRIGNOGAN   4
#           sourcemmsi  speedoverground       lon       lat           t  \
# 12462748   228762000              0.0 -4.506695  48.37458  1456988400
# 12746034   228762000              0.0 -4.506695  48.37458  1456988400
#
#          station_name  Ff
# 12462748     OUESSANT   7
# 12746034     OUESSANT   7
#          sourcemmsi  speedoverground       lon        lat           t  \
# 8502524   228186700            102.3 -4.698999  48.321835  1453302000
#
#         station_name  Ff
# 8502524     OUESSANT   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 6968005   228017700              0.1 -4.485722  48.38107  1451458800
# 6968006   227574020             15.4 -4.413442  48.29532  1451458800
#
#         station_name  Ff
# 6968005    BRIGNOGAN   6
# 6968006    BRIGNOGAN   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 3856393    227574020              2.2 -4.495892  48.352936  1447772400
# 15567076   227008170             12.2 -4.738165  48.314934  1447772400
#
#          station_name  Ff
# 3856393     BRIGNOGAN   6
# 15567076     OUESSANT   6
#          sourcemmsi  speedoverground       lon      lat           t  \
# 2189816   228017700              0.0 -4.485743  48.3811  1445929200
#
#         station_name  Ff
# 2189816    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11689415   227574020              0.0 -4.496620  48.382416  1456185600
# 11689416   227941000              0.0 -4.327227  48.100082  1456185600
#
#          station_name  Ff
# 11689415    BRIGNOGAN   3
# 11689416    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon        lat           t  \
# 9807457   227019400              5.2 -4.480155  48.329075  1454342400
#
#         station_name  Ff
# 9807457    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14565774   234056000              0.1 -4.518405  48.367350  1459069200
# 14565775   226263000             17.3 -4.601143  48.319614  1459069200
#
#          station_name  Ff
# 14565774     OUESSANT   6
# 14565775     OUESSANT   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12969140   228186700            102.3 -4.512665  48.370834  1457226000
# 12969141   228762000              0.1 -4.506767  48.374615  1457226000
#
#          station_name  Ff
# 12969140     OUESSANT   5
# 12969141     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10818954   227003050              0.0 -4.485928  48.380733  1455382800
#
#          station_name  Ff
# 10818954    BRIGNOGAN   7
#          sourcemmsi  speedoverground      lon       lat           t  \
# 5901018   227580520              0.0 -4.49707  48.37956  1449853200
#
#         station_name  Ff
# 5901018    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 4136900   227999400             14.6 -4.484295  48.304413  1448010000
#
#         station_name  Ff
# 4136900    BRIGNOGAN   4
#           sourcemmsi  speedoverground     lon       lat           t  \
# 15276160   227003050              0.0 -4.4859  48.38077  1446166800
#
#          station_name  Ff
# 15276160    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 15011249   228292700             12.2 -4.661165  47.938667  1444323600
#
#          station_name  Ff
# 15011249     OUESSANT   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13886640   226318000             25.0 -5.152332  47.956665  1458266400
#
#          station_name  Ff
# 13886640     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11933555   227941000              0.0 -4.327209  48.100098  1456423200
#
#          station_name  Ff
# 11933555    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10071446   227574020              0.0 -4.496682  48.382484  1454580000
#
#          station_name  Ff
# 10071446    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 7855391   227580520              0.0 -4.497028  48.379513  1452736800
#
#         station_name  Ff
# 7855391    BRIGNOGAN   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6669779   304927000              8.0 -4.788047  48.261330  1450893600
# 6669780   228051000              0.0 -4.485077  48.381325  1450893600
#
#         station_name  Ff
# 6669779     OUESSANT   6
# 6669780    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 5207776    227574020              0.0 -4.497043  48.382175  1449050400
# 5207777    227705102              0.0 -4.495399  48.383625  1449050400
# 15848667   228336000              8.8 -4.849680  48.199100  1449050400
# 18438608   227578460              5.1 -4.402663  48.320152  1449050400
#
#          station_name  Ff
# 5207776     BRIGNOGAN   3
# 5207777     BRIGNOGAN   3
# 15848667     OUESSANT   5
# 18438608    BRIGNOGAN   3
#          sourcemmsi  speedoverground      lon        lat           t  \
# 3384472   228051000              0.0 -4.48512  48.381306  1447207200
# 3384473   227392000              9.4 -4.84113  48.208160  1447207200
#
#         station_name  Ff
# 3384472    BRIGNOGAN   2
# 3384473     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14723303   227114300              3.6 -4.788572  48.355800  1459306800
# 14723304   227730220             19.6 -4.486953  48.375233  1459306800
#
#          station_name  Ff
# 14723303     OUESSANT   4
# 14723304    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13180358   227705102              0.0 -4.497053  48.382180  1457463600
# 13180359   228762000              0.0 -4.506737  48.374573  1457463600
#
#          station_name  Ff
# 13180358    BRIGNOGAN   4
# 13180359     OUESSANT   5
#           sourcemmsi  speedoverground      lon       lat           t  \
# 11081338   227580520              0.0 -4.49705  48.37953  1455620400
#
#          station_name  Ff
# 11081338    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6031884   228186700              0.0 -4.442165  48.321835  1450090800
#
#         station_name  Ff
# 6031884    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 4433753   228051000              0.0 -4.485098  48.381348  1448247600
# 4433754   305600000             15.8 -5.144498  48.169666  1448247600
#
#         station_name  Ff
# 4433753    BRIGNOGAN   4
# 4433754     OUESSANT   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 18145093   227754790              8.1 -4.538432  48.349293  1444561200
#
#          station_name  Ff
# 18145093     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14053831   228299900             10.3 -4.825605  48.123436  1458504000
#
#          station_name  Ff
# 14053831     OUESSANT   6
#           sourcemmsi  speedoverground       lon       lat           t  \
# 12133280   227002630              0.0 -4.848657  48.03903  1456660800
#
#          station_name  Ff
# 12133280     OUESSANT   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10335594   228015700              0.0 -4.325107  48.098160  1454817600
# 10335595   227574020              0.0 -4.495473  48.383595  1454817600
# 17132857   228043800             11.6 -4.758130  48.133232  1454817600
# 17132858   228043800             11.6 -4.758130  48.133232  1454817600
#
#          station_name  Ff
# 10335594    BRIGNOGAN   7
# 10335595    BRIGNOGAN   7
# 17132857     OUESSANT   6
# 17132858     OUESSANT   6
#          sourcemmsi  speedoverground       lon       lat           t  \
# 6765585   228051000              0.1 -4.485098  48.38132  1451131200
#
#         station_name  Ff
# 6765585    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5435281   538002973              0.0 -4.471882  48.381516  1449288000
#
#         station_name  Ff
# 5435281    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon       lat           t  \
# 3609051   228051000              0.0 -4.485086  48.38133  1447444800
#
#         station_name  Ff
# 3609051    BRIGNOGAN   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 1887355   228762000            102.3 -4.451785  48.381065  1445601600
#
#         station_name  Ff
# 1887355    BRIGNOGAN   3
#        sourcemmsi  speedoverground       lon        lat           t  \
# 90119   227574020              0.0 -4.495487  48.383606  1443758400
#
#       station_name  Ff
# 90119    BRIGNOGAN   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13416158   228762000              0.0 -4.506755  48.374615  1457701200
# 13416159   227485000              8.1 -4.928688  48.127464  1457701200
#
#          station_name  Ff
# 13416158     OUESSANT   2
# 13416159     OUESSANT   2
#          sourcemmsi  speedoverground       lon        lat           t  \
# 9551934   228293000              8.9 -4.652898  48.187267  1454014800
# 9551935   228144000              5.3 -4.678877  48.216230  1454014800
#
#         station_name  Ff
# 9551934     OUESSANT   5
# 9551935     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 7428312    227635210              0.0 -4.497487  48.379800  1452171600
# 7428313    227705102              0.0 -4.497020  48.379530  1452171600
# 16540299   228336000              1.2 -4.755527  48.134552  1452171600
#
#          station_name  Ff
# 7428312     BRIGNOGAN   7
# 7428313     BRIGNOGAN   7
# 16540299     OUESSANT   7
#           sourcemmsi  speedoverground       lon       lat           t  \
# 14288992   227574020              0.0 -4.495353  48.38368  1458741600
#
#          station_name  Ff
# 14288992    BRIGNOGAN   2
#           sourcemmsi  speedoverground      lon        lat           t  \
# 12397979   227003050              0.0 -4.48574  48.381134  1456898400
# 12681265   227003050              0.0 -4.48574  48.381134  1456898400
#
#          station_name  Ff
# 12397979    BRIGNOGAN   7
# 12681265    BRIGNOGAN   7
#          sourcemmsi  speedoverground       lon       lat           t  \
# 3788012   227297000              0.0 -4.482040  48.38088  1447682400
# 3788013   228240000              8.9 -4.870976  47.91298  1447682400
#
#         station_name  Ff
# 3788012    BRIGNOGAN   3
# 3788013     OUESSANT   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 2085382   228394000              1.0 -4.901061  48.215034  1445839200
#
#         station_name  Ff
# 2085382     OUESSANT   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 302212     259019000              0.1 -4.514780  48.369335  1443996000
# 14925631   228186700              0.1 -4.512498  48.370834  1443996000
#
#          station_name  Ff
# 302212       OUESSANT   7
# 14925631     OUESSANT   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13573306   228762000              0.0 -4.506778  48.374615  1457938800
#
#          station_name  Ff
# 13573306     OUESSANT   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11592404   227319570              8.3 -4.362057  48.159260  1456095600
# 11592405   227941000              0.0 -4.327218  48.100086  1456095600
# 11592406   305600000             15.9 -5.014498  47.874170  1456095600
#
#          station_name  Ff
# 11592404    BRIGNOGAN   4
# 11592405    BRIGNOGAN   4
# 11592406     OUESSANT   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 6434592   227580520              0.0 -4.497082  48.37957  1450566000
#
#         station_name  Ff
# 6434592    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 4905510   228051000              0.0 -4.485092  48.38129  1448722800
#
#         station_name  Ff
# 4905510    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14495354   226177000              0.1 -4.325285  48.098167  1458979200
# 14495355   234056000              0.0 -4.518485  48.367374  1458979200
# 14495356   228017700             14.6 -4.689070  48.329320  1458979200
#
#          station_name  Ff
# 14495354    BRIGNOGAN   5
# 14495355     OUESSANT   7
# 14495356     OUESSANT   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12896141   228186700            102.3 -4.512665  48.370834  1457136000
#
#          station_name  Ff
# 12896141     OUESSANT   8
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10754179   227003050              0.0 -4.485928  48.380720  1455292800
# 17210370   304010986              8.6 -5.042645  48.187454  1455292800
#
#          station_name  Ff
# 10754179    BRIGNOGAN   7
# 17210370     OUESSANT   6
#          sourcemmsi  speedoverground       lon       lat           t  \
# 8738079   227612860             19.5 -4.471408  48.33818  1453449600
#
#         station_name  Ff
# 8738079    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 7074170   227003050              0.0 -4.485915  48.380795  1451606400
#
#         station_name  Ff
# 7074170    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5821776   227612860              6.1 -4.495150  48.378870  1449763200
# 5821777   227577000              8.2 -4.524209  48.356346  1449763200
#
#         station_name  Ff
# 5821776    BRIGNOGAN   4
# 5821777     OUESSANT   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 4016662   227008170             11.6 -4.869999  48.404835  1447920000
#
#         station_name  Ff
# 4016662     OUESSANT   5
#           sourcemmsi  speedoverground       lon       lat           t  \
# 18122753   235113366              7.2 -4.714228  48.15049  1444233600
#
#          station_name  Ff
# 18122753     OUESSANT   3
#           sourcemmsi  speedoverground      lon       lat           t  \
# 13807228   228186700            102.3 -4.91807  48.27289  1458176400
#
#          station_name  Ff
# 13807228     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11850290   227941000              0.0 -4.327209  48.100094  1456333200
# 17425637   227318010              0.6 -4.338882  48.123665  1456333200
# 17425638   227002330              0.1 -4.486045  48.380740  1456333200
#
#          station_name  Ff
# 11850290    BRIGNOGAN   7
# 17425637    BRIGNOGAN   7
# 17425638    BRIGNOGAN   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 9951543    227705102              0.1 -4.495470  48.383682  1454490000
# 9951544    227580520              0.0 -4.497083  48.379555  1454490000
# 17055611   226263000              0.1 -4.485717  48.379814  1454490000
#
#          station_name  Ff
# 9951543     BRIGNOGAN   5
# 9951544     BRIGNOGAN   5
# 17055611    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 6601711   228793000              0.0 -4.516743  48.36884  1450803600
#
#         station_name  Ff
# 6601711     OUESSANT   7
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5115891   227577000              0.0 -4.486404  48.381844  1448960400
# 5115892   227574020              0.0 -4.497055  48.382180  1448960400
# 5115893   228344800              0.0 -4.478333  48.383125  1448960400
#
#         station_name  Ff
# 5115891    BRIGNOGAN   3
# 5115892    BRIGNOGAN   3
# 5115893    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon       lat           t  \
# 13096314   227635210              9.8 -4.491893  48.37493  1457373600
# 13096315   227705102              0.0 -4.497014  48.38214  1457373600
#
#          station_name  Ff
# 13096314    BRIGNOGAN   5
# 13096315    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon      lat           t  \
# 10961092   228051000              0.0 -4.485093  48.3813  1455530400
#
#          station_name  Ff
# 10961092    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 9088207   228186700            102.3 -4.512665  48.370834  1453687200
#
#         station_name  Ff
# 9088207     OUESSANT   6
#          sourcemmsi  speedoverground       lon       lat           t  \
# 7215789   227003050              0.0 -4.485928  48.38077  1451844000
#
#         station_name  Ff
# 7215789    BRIGNOGAN   5
#          sourcemmsi  speedoverground      lon       lat           t  \
# 4312637   226263000              0.2 -4.68108  48.34358  1448157600
#
#         station_name  Ff
# 4312637     OUESSANT   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 2510304   227580520              0.0 -4.497053  48.379467  1446314400
#
#         station_name  Ff
# 2510304    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon       lat           t  \
# 13985774   227003050              0.0 -4.485657  48.38114  1458414000
#
#          station_name  Ff
# 13985774    BRIGNOGAN   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10253524   227574020              0.0 -4.495490  48.383700  1454727600
# 10253525   234056000              0.0 -4.518473  48.367416  1454727600
#
#          station_name  Ff
# 10253524    BRIGNOGAN   4
# 10253525     OUESSANT   7
#          sourcemmsi  speedoverground       lon       lat           t  \
# 8019984   227005550              0.7 -4.483592  48.37891  1452884400
#
#         station_name  Ff
# 8019984    BRIGNOGAN   7
#          sourcemmsi  speedoverground       lon       lat           t  \
# 5354282   227574020              0.0 -4.497055  48.38217  1449198000
#
#         station_name  Ff
# 5354282    BRIGNOGAN   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14858461   227590980              0.2 -4.487452  48.209553  1459454400
# 14858462   228051000              0.0 -4.485117  48.381320  1459454400
# 18082169   228213700              0.4 -4.487514  48.206875  1459454400
#
#          station_name  Ff
# 14858461     OUESSANT   3
# 14858462    BRIGNOGAN   4
# 18082169     OUESSANT   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13324195   228762000              0.0 -4.506755  48.374615  1457611200
# 13324196   234056000              2.9 -4.522287  48.350090  1457611200
# 18922073   227632830              6.6 -4.435564  48.322227  1457611200
#
#          station_name  Ff
# 13324195     OUESSANT   5
# 13324196     OUESSANT   5
# 18922073    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 7360624   228017700             14.0 -4.790483  48.358063  1452081600
# 7360625   228051000              0.0 -4.484558  48.381160  1452081600
#
#         station_name  Ff
# 7360624     OUESSANT   5
# 7360625    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 1045217    227580520              0.0 -4.497112  48.379536  1444708800
# 15071981   226263000              0.1 -4.485747  48.379826  1444708800
#
#          station_name  Ff
# 1045217     BRIGNOGAN   5
# 15071981    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 9407698   228186700            102.3 -4.512665  48.370834  1453924800
# 9407699   228302900              8.5 -4.400960  48.191840  1453924800
#
#         station_name  Ff
# 9407698     OUESSANT   5
# 9407699    BRIGNOGAN   5
#           sourcemmsi  speedoverground      lon        lat           t  \
# 14198637   227635210              0.0 -4.49705  48.382145  1458651600
# 14198638   227002630              0.0 -4.84868  48.039032  1458651600
#
#          station_name  Ff
# 14198637    BRIGNOGAN   3
# 14198638     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10470261   234056000              0.0 -4.518457  48.367325  1454965200
#
#          station_name  Ff
# 10470261     OUESSANT   6
#          sourcemmsi  speedoverground       lon       lat           t  \
# 8244154   228186700            102.3 -4.513021  48.37112  1453122000
# 8244155   227635210              0.0 -4.496588  48.38241  1453122000
#
#         station_name  Ff
# 8244154     OUESSANT   3
# 8244155    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6867097   227705102              0.0 -4.495257  48.383633  1451278800
#
#         station_name  Ff
# 6867097    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5519015   228051000              0.0 -4.485088  48.381332  1449435600
#
#         station_name  Ff
# 5519015    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon      lat           t  \
# 3728016   227705102              0.1 -4.496543  48.3824  1447592400
#
#         station_name  Ff
# 3728016    BRIGNOGAN   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13506562   228762000              0.1 -4.506767  48.374615  1457848800
# 13506563   227270000             10.2 -4.680287  48.311615  1457848800
# 13506564   999999999              9.1 -4.529934  48.351760  1457848800
#
#          station_name  Ff
# 13506562     OUESSANT   4
# 13506563     OUESSANT   4
# 13506564     OUESSANT   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11498808   228137900              3.5 -5.703737  47.718704  1456005600
# 11498809   227003050              0.0 -4.485882  48.380764  1456005600
# 11498810   235005150              9.5 -4.787125  48.318153  1456005600
#
#          station_name  Ff
# 11498808     OUESSANT   5
# 11498809    BRIGNOGAN   5
# 11498810     OUESSANT   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 9657148   227148000              9.2 -4.816638  48.25996  1454162400
#
#         station_name  Ff
# 9657148     OUESSANT   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 4818034    227574020              0.0 -4.497038  48.382206  1448632800
# 15768990   227008170             11.3 -4.771498  48.322834  1448632800
#
#          station_name  Ff
# 4818034      OUESSANT   5
# 15768990     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14420340   234056000              0.0 -4.518415  48.367565  1458889200
# 14420341   227635210             16.2 -4.497191  48.297400  1458889200
#
#          station_name  Ff
# 14420340     OUESSANT   5
# 14420341     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10677375   227003050              0.0 -4.485902  48.380750  1455202800
# 17192884   234056000              0.0 -4.518785  48.367455  1455202800
#
#          station_name  Ff
# 10677375    BRIGNOGAN   3
# 17192884     OUESSANT   4
#          sourcemmsi  speedoverground       lon       lat           t  \
# 8604792   228186700            102.3 -4.512593  48.37084  1453359600
# 8604793   227574020              0.0 -4.497139  48.38232  1453359600
#
#         station_name  Ff
# 8604792     OUESSANT   6
# 8604793    BRIGNOGAN   4
#          sourcemmsi  speedoverground      lon        lat           t  \
# 7004429   228051000              0.1 -4.48455  48.381107  1451516400
#
#         station_name  Ff
# 7004429    BRIGNOGAN   6
#           sourcemmsi  speedoverground       lon       lat           t  \
# 15995719   227574020             16.7 -4.490157  48.36883  1449673200
#
#          station_name  Ff
# 15995719    BRIGNOGAN   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 18350753   227315110              7.2 -4.466985  48.362625  1447830000
# 18350754   227590030              7.5 -4.479475  48.357990  1447830000
#
#          station_name  Ff
# 18350753    BRIGNOGAN   4
# 18350754    BRIGNOGAN   4
#         sourcemmsi  speedoverground       lon        lat           t  \
# 452080   227009310             16.2 -4.716043  48.313385  1444143600
# 452081   227143600             10.0 -4.559423  48.120773  1444143600
#
#        station_name  Ff
# 452080     OUESSANT   7
# 452081     OUESSANT   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13720596   228762000              0.0 -4.506753  48.374615  1458086400
# 17846680   249616000              0.4 -4.332065  48.115950  1458086400
#
#          station_name  Ff
# 13720596     OUESSANT   5
# 17846680    BRIGNOGAN   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11739557   228186700            102.3 -4.512665  48.370834  1456243200
# 11739558   227941000              0.0 -4.327222  48.100090  1456243200
#
#          station_name  Ff
# 11739557     OUESSANT   2
# 11739558    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 9857271    234056000              6.7 -4.481385  48.205925  1454400000
# 9857272    227580520              0.0 -4.497055  48.379560  1454400000
# 9857273    227730220              8.2 -4.483917  48.337250  1454400000
# 18714071   227641920              3.0 -4.492667  48.319670  1454400000
#
#          station_name  Ff
# 9857271      OUESSANT   6
# 9857272     BRIGNOGAN   4
# 9857273     BRIGNOGAN   4
# 18714071     OUESSANT   6
#           sourcemmsi  speedoverground       lon       lat           t  \
# 16652375   228236600              0.1 -4.326883  48.09865  1452556800
#
#          station_name  Ff
# 16652375    BRIGNOGAN   7
# ...
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12272198   227319570              8.9 -4.362477  48.152060  1456783200
# 12272199   227318020              9.0 -4.381250  48.163548  1456783200
# 12272200   228037600              0.7 -4.471137  48.228860  1456783200
# 12272201   227941000              0.0 -4.327217  48.100100  1456783200
# 12272202   227705102              0.0 -4.496511  48.382378  1456783200
#
#          station_name  Ff
# 12272198    BRIGNOGAN   2
# 12272199    BRIGNOGAN   2
# 12272200    BRIGNOGAN   2
# 12272201    BRIGNOGAN   2
# 12272202    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 16754893   228336000              9.1 -4.775165  48.199528  1453096800
#
#          station_name  Ff
# 16754893     OUESSANT   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5506008   228051000              0.0 -4.485074  48.381325  1449410400
#
#         station_name  Ff
# 5506008    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon        lat           t  \
# 1982207   227091000              0.0 -4.481508  48.381214  1445724000
#
#         station_name  Ff
# 1982207    BRIGNOGAN   5
#         sourcemmsi  speedoverground       lon        lat           t  \
# 211215   227306100              4.3 -4.593377  48.319855  1443880800
# 211216   227705102              0.0 -4.495468  48.383656  1443880800
# 211217   227002330              0.0 -4.485927  48.380688  1443880800
#
#        station_name  Ff
# 211215     OUESSANT   2
# 211216    BRIGNOGAN   2
# 211217    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11475851   227941000              0.0 -4.327217  48.100094  1455980400
#
#          station_name  Ff
# 11475851    BRIGNOGAN   6
#          sourcemmsi  speedoverground       lon       lat           t  \
# 7538289   228017700              0.0 -4.485704  48.38108  1452294000
#
#         station_name  Ff
# 7538289    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14398503   227574020              0.0 -4.495340  48.383650  1458864000
# 14398504   227391000              0.0 -4.323480  48.097870  1458864000
# 14398505   234056000              0.0 -4.518533  48.367386  1458864000
#
#          station_name  Ff
# 14398503    BRIGNOGAN   4
# 14398504    BRIGNOGAN   4
# 14398505     OUESSANT   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12496773   228762000              3.5 -4.495017  48.347813  1457020800
# 12496774   518866000              8.0 -5.236820  48.048430  1457020800
# 12496775   227635210             18.0 -4.441782  48.309753  1457020800
# 12780059   228762000              3.5 -4.495017  48.347813  1457020800
# 12780060   518866000              8.0 -5.236820  48.048430  1457020800
# 12780061   227635210             18.0 -4.441782  48.309753  1457020800
#
#          station_name  Ff
# 12496773    BRIGNOGAN   3
# 12496774     OUESSANT   5
# 12496775    BRIGNOGAN   3
# 12780059    BRIGNOGAN   3
# 12780060     OUESSANT   5
# 12780061    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon        lat           t  \
# 8568627   228186700            102.3 -4.512603  48.370830  1453334400
# 8568628   227008170              0.0 -4.486132  48.381565  1453334400
# 8568629   227300000              1.8 -4.718883  48.159170  1453334400
#
#         station_name  Ff
# 8568627     OUESSANT   6
# 8568628    BRIGNOGAN   4
# 8568629     OUESSANT   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6989646   228051000              1.2 -4.459400  48.378834  1451491200
# 6989647   227730220              7.4 -4.479247  48.356070  1451491200
# 6989648   227705102             18.6 -4.444782  48.311264  1451491200
# 6989649   228041600             12.3 -4.843003  48.277565  1451491200
# 6989650   227574020              6.4 -4.495798  48.383010  1451491200
#
#         station_name  Ff
# 6989646    BRIGNOGAN   4
# 6989647    BRIGNOGAN   4
# 6989648    BRIGNOGAN   4
# 6989649     OUESSANT   5
# 6989650    BRIGNOGAN   4
#          sourcemmsi  speedoverground      lon        lat           t  \
# 5705599   577228000              2.7 -4.84541  48.189583  1449648000
#
#         station_name  Ff
# 5705599     OUESSANT   4
#          sourcemmsi  speedoverground      lon       lat           t  \
# 3882727   228051000              0.0 -4.48507  48.38132  1447804800
#
#         station_name  Ff
# 3882727    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13688093   228762000              0.1 -4.506735  48.374653  1458061200
# 13688094   228160000              9.3 -4.434332  48.127260  1458061200
#
#          station_name  Ff
# 13688093     OUESSANT   5
# 13688094    BRIGNOGAN   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11718825   227941000              0.0 -4.327202  48.100094  1456218000
# 11718826   227574020              0.0 -4.496548  48.382380  1456218000
# 11718827   228186700            102.3 -4.512593  48.370853  1456218000
# 11718828   227297000              7.1 -4.568877  48.343800  1456218000
#
#          station_name  Ff
# 11718825    BRIGNOGAN   2
# 11718826    BRIGNOGAN   2
# 11718827     OUESSANT   3
# 11718828     OUESSANT   3
#          sourcemmsi  speedoverground       lon       lat           t  \
# 9838316   227705102              0.0 -4.495462  48.38365  1454374800
#
#         station_name  Ff
# 9838316    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon       lat           t  \
# 16644102   228236600              0.6 -4.326915  48.09864  1452531600
#
#          station_name  Ff
# 16644102    BRIGNOGAN   7
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6514493   228236700              5.4 -4.861842  47.948124  1450688400
#
#         station_name  Ff
# 6514493     OUESSANT   6
#          sourcemmsi  speedoverground      lon       lat           t  \
# 3178036   228051000              0.0 -4.48509  48.38132  1447002000
#
#         station_name  Ff
# 3178036    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 1457860   228186700              0.0 -4.512498  48.370834  1445158800
#
#         station_name  Ff
# 1457860     OUESSANT   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12989197   227574020              0.0 -4.497479  48.379753  1457258400
# 12989198   228762000              0.0 -4.506770  48.374620  1457258400
#
#          station_name  Ff
# 12989197    BRIGNOGAN   5
# 12989198     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10849552   227003050              0.0 -4.485939  48.380745  1455415200
#
#          station_name  Ff
# 10849552    BRIGNOGAN   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 8901666   228186700            102.3 -4.512589  48.370840  1453572000
# 8901667   228109000              5.5 -4.680918  48.128227  1453572000
#
#         station_name  Ff
# 8901666     OUESSANT   5
# 8901667     OUESSANT   5
#           sourcemmsi  speedoverground       lon       lat           t  \
# 7144453    227003050              0.0 -4.485917  48.38073  1451728800
# 16427636   304088000              2.4 -4.433942  48.16476  1451728800
#
#          station_name  Ff
# 7144453     BRIGNOGAN   9
# 16427636    BRIGNOGAN   9
#           sourcemmsi  speedoverground       lon       lat           t  \
# 4177828    228051000              0.4 -4.459987  48.38291  1448042400
# 4177829    226263000              0.1 -4.485730  48.37979  1448042400
# 15629556   259019000              0.0 -4.514342  48.36900  1448042400
#
#          station_name  Ff
# 4177828     BRIGNOGAN   6
# 4177829     BRIGNOGAN   6
# 15629556     OUESSANT   5
#           sourcemmsi  speedoverground       lon       lat           t  \
# 15286034   227003050              0.0 -4.485933  48.38072  1446199200
#
#          station_name  Ff
# 15286034    BRIGNOGAN   4
#         sourcemmsi  speedoverground       lon        lat           t  \
# 750854   351020000              0.0 -4.471932  48.381317  1444356000
#
#        station_name  Ff
# 750854    BRIGNOGAN   2
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10111307   234056000              6.9 -4.354382  48.131935  1454612400
#
#          station_name  Ff
# 10111307    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13917113   228109000              3.0 -5.030752  48.176826  1458298800
#
#          station_name  Ff
# 13917113     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 16696861   228336000              2.3 -4.833537  48.230667  1452769200
#
#          station_name  Ff
# 16696861     OUESSANT   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 6688400   227297000              0.0 -4.481910  48.38092  1450926000
# 6688401   228051000              0.1 -4.485102  48.38134  1450926000
#
#         station_name  Ff
# 6688400    BRIGNOGAN   4
# 6688401    BRIGNOGAN   4
#          sourcemmsi  speedoverground       lon        lat           t  \
# 5246729   538002973              5.1 -4.476232  48.363766  1449082800
# 5246730   227730220              1.2 -4.505018  48.359040  1449082800
#
#         station_name  Ff
# 5246729    BRIGNOGAN   3
# 5246730     OUESSANT   6
#          sourcemmsi  speedoverground       lon       lat           t  \
# 3411365   228068600              0.0 -4.482327  48.38086  1447239600
#
#         station_name  Ff
# 3411365    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14751302   228064900              0.2 -4.516332  48.330444  1459339200
#
#          station_name  Ff
# 14751302     OUESSANT   3
#           sourcemmsi  speedoverground      lon        lat           t  \
# 13216063   636015129              3.6 -4.46112  48.375040  1457496000
# 17746440   227006750              3.7 -4.46083  48.374226  1457496000
#
#          station_name  Ff
# 13216063    BRIGNOGAN   9
# 17746440    BRIGNOGAN   9
#          sourcemmsi  speedoverground       lon        lat           t  \
# 9248392   227635210              0.1 -4.495450  48.383667  1453809600
# 9248393   228186700            102.3 -4.512567  48.370846  1453809600
#
#         station_name  Ff
# 9248392    BRIGNOGAN   5
# 9248393     OUESSANT   7
#          sourcemmsi  speedoverground       lon        lat           t  \
# 7277503   227003050              0.0 -4.485903  48.380737  1451966400
#
#         station_name  Ff
# 7277503    BRIGNOGAN   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 16074062   228064900              0.0 -4.511715  48.364685  1450123200
#
#          station_name  Ff
# 16074062     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 4476282    227091000              0.0 -4.478163  48.383186  1448280000
# 15690754   211211220             12.2 -4.802135  48.335392  1448280000
# 18376796   227521960              0.0 -4.488272  48.378387  1448280000
#
#          station_name  Ff
# 4476282     BRIGNOGAN   2
# 15690754     OUESSANT   2
# 18376796    BRIGNOGAN   2
#          sourcemmsi  speedoverground       lon        lat           t  \
# 2615425   224038000              7.2 -5.224465  47.333748  1446436800
# 2615426   227590000              6.3 -5.590380  47.011692  1446436800
#
#         station_name  Ff
# 2615425     OUESSANT   5
# 2615426     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 10360604   228015700              0.4 -4.322835  48.114910  1454850000
# 10360605   226178000              0.0 -4.323955  48.098034  1454850000
#
#          station_name  Ff
# 10360604    BRIGNOGAN   5
# 10360605    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14075151   228736000              0.0 -4.514653  48.369915  1458536400
#
#          station_name  Ff
# 14075151     OUESSANT   6
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12167710   227941000              0.0 -4.327233  48.100086  1456693200
# 12167711   228037600             10.4 -4.321682  48.130474  1456693200
# 17489107   227436000             11.1 -4.833082  47.908817  1456693200
#
#          station_name  Ff
# 12167710    BRIGNOGAN   6
# 12167711    BRIGNOGAN   6
# 17489107     OUESSANT   6
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6776889   227705102              0.0 -4.495286  48.383648  1451163600
#
#         station_name  Ff
# 6776889    BRIGNOGAN   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 5456895    309165000              9.9 -4.565182  48.346718  1449320400
# 15916177   226263000              1.0 -4.586500  48.284935  1449320400
#
#          station_name  Ff
# 5456895      OUESSANT   7
# 15916177     OUESSANT   7
#           sourcemmsi  speedoverground       lon        lat           t  \
# 11407762   227574020              0.0 -4.496727  48.382435  1455890400
#
#          station_name  Ff
# 11407762    BRIGNOGAN   5
#          sourcemmsi  speedoverground      lon      lat           t  \
# 9574601   356101000              0.0 -4.46477  48.3831  1454047200
#
#         station_name  Ff
# 9574601    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon        lat           t  \
# 6285274   228032800             10.7 -4.755215  48.084740  1450360800
# 6285275   999999999              0.0 -4.513343  48.369907  1450360800
#
#         station_name  Ff
# 6285274     OUESSANT   5
# 6285275     OUESSANT   5
#           sourcemmsi  speedoverground       lon        lat           t  \
# 14322898   227590980              8.7 -4.422443  48.129253  1458774000
# 14322899   228293000              9.7 -4.642648  48.176450  1458774000
# 14322900   227574020              0.0 -4.495327  48.383633  1458774000
#
#          station_name  Ff
# 14322898    BRIGNOGAN   3
# 14322899     OUESSANT   3
# 14322900    BRIGNOGAN   3
#           sourcemmsi  speedoverground       lon        lat           t  \
# 12427258   234056000              4.4 -4.443188  48.173843  1456930800
# 12710544   234056000              4.4 -4.443188  48.173843  1456930800
# 17553140   228762000              5.1 -4.502600  48.332330  1456930800
# 17634881   228762000              5.1 -4.502600  48.332330  1456930800
#
#          station_name  Ff
# 12427258    BRIGNOGAN   9
# 12710544    BRIGNOGAN   9
# 17553140     OUESSANT   9
# 17634881     OUESSANT   9
#           sourcemmsi  speedoverground       lon       lat           t  \
# 10564116   226178000              0.0 -4.323908  48.09804  1455087600
#
#          station_name  Ff
# 10564116    BRIGNOGAN   5
#          sourcemmsi  speedoverground       lon       lat           t  \
# 6938257   228051000              0.0 -4.484549  48.38113  1451401200
#
#         station_name  Ff
# 6938257    BRIGNOGAN   4
#           sourcemmsi  speedoverground       lon        lat           t  \
# 5615943    228051000              0.0 -4.485110  48.381332  1449558000
# 5615944    227019400              0.1 -4.475972  48.294502  1449558000
# 18468762   227611930              7.1 -4.485503  48.361100  1449558000
#
#          station_name  Ff
# 5615943     BRIGNOGAN   3
# 5615944     BRIGNOGAN   3
# 18468762    BRIGNOGAN   3
#          sourcemmsi  speedoverground       lon       lat           t  \
# 3812502   227297000              0.0 -4.482032  48.38088  1447714800
#
#         station_name  Ff
# 3812502    BRIGNOGAN   7
#           sourcemmsi  speedoverground      lon        lat           t  \
# 329126     227730220             14.6 -4.48779  48.374786  1444028400
# 14930705   227860000              6.8 -4.76410  48.057587  1444028400
#
#          station_name  Ff
# 329126      BRIGNOGAN   4
# 14930705     OUESSANT   6

# %%
#deyterh lysh xronos 60 lepta
start_time=time.time()
o={}
for k in c:
    df_ships = df_1.loc[df_1['t']==k]
    df_weather = weather_data.loc[weather_data['local_time']==k]
    df_ships['station_name']=0
    df_ships['Ff'] = 0
    for i in range(len(df_ships)):
        x1 = df_ships.iloc[i]['lon']
        y1 = df_ships.iloc[i]['lat']
        dist=10000000
        for j in range(len(df_weather)):
            x2 = df_weather.iloc[j]['longitude']
            y2 = df_weather.iloc[j]['latitude']
            dist_i = calculateDistance(x1,y1,x2,y2)
        
            if dist_i<dist:
                dist = dist_i
                df_ships.iloc[i,-2]=df_weather.iloc[j]['station_name']
                df_ships.iloc[i,-1]=wind_bft(df_weather.iloc[j]['Ff'])
    o[k]= df_ships
print(time.time()-start_time)

# %%
final_data=[]
for i in o.values():
    print(i)
    final_data.append(i)

# %%
data = pd.concat(final_data)

# %%
teliko=pd.DataFrame(data)

# %%
pd.DataFrame(teliko)
# Out:
#           sourcemmsi  speedoverground       lon        lat           t  \
# 13602158   227592820             16.9 -4.483425  48.350903  1457971200
# 13602159   228762000              0.2 -4.506792  48.374588  1457971200
# 11624163   226178000              0.0 -4.325843  48.098220  1456128000
# 6457456    228051000              0.0 -4.485086  48.381320  1450598400
# 6457457    227580520              0.0 -4.497093  48.379566  1450598400
# ...              ...              ...       ...        ...         ...
# 5615944    227019400              0.1 -4.475972  48.294502  1449558000
# 18468762   227611930              7.1 -4.485503  48.361100  1449558000
# 3812502    227297000              0.0 -4.482032  48.380880  1447714800
# 329126     227730220             14.6 -4.487790  48.374786  1444028400
# 14930705   227860000              6.8 -4.764100  48.057587  1444028400
#
#          station_name   Ff
# 13602158    BRIGNOGAN  7.0
# 13602159     OUESSANT  6.0
# 11624163    BRIGNOGAN  4.0
# 6457456     BRIGNOGAN  3.0
# 6457457     BRIGNOGAN  3.0
# ...               ...  ...
# 5615944     BRIGNOGAN  3.0
# 18468762    BRIGNOGAN  3.0
# 3812502     BRIGNOGAN  7.0
# 329126      BRIGNOGAN  4.0
# 14930705     OUESSANT  6.0
#
# [4934 rows x 7 columns]

# %%
teliko_pred=pd.DataFrame(teliko)

# %%
map_r1 = spark.createDataFrame(teliko)

# %%
map_r1.show()
# Out:
# +----------+---------------+-------------------+------------------+----------+------------+---+
# |sourcemmsi|speedoverground|                lon|               lat|         t|station_name| Ff|
# +----------+---------------+-------------------+------------------+----------+------------+---+
# | 227592820|           16.9|          -4.483425|         48.350903|1457971200|   BRIGNOGAN|7.0|
# | 228762000|            0.2|         -4.5067916|         48.374588|1457971200|    OUESSANT|6.0|
# | 226178000|            0.0|         -4.3258433|          48.09822|1456128000|   BRIGNOGAN|4.0|
# | 228051000|            0.0|         -4.4850864|          48.38132|1450598400|   BRIGNOGAN|3.0|
# | 227580520|            0.0|-4.4970930000000005|         48.379566|1450598400|   BRIGNOGAN|3.0|
# | 226318000|           19.6|         -4.7592835|48.212703999999995|1450598400|    OUESSANT|5.0|
# | 356071000|            0.2| -4.322503599999999|           48.1183|1452441600|   BRIGNOGAN|4.0|
# | 228394000|            2.1|          -4.911723|         48.104588|1454284800|    OUESSANT|6.0|
# | 228064900|            0.0|          -4.511863|48.364684999999994|1448755200|    OUESSANT|7.0|
# | 228186700|            0.0|-4.5128317000000004|         48.370667|1446912000|    OUESSANT|4.0|
# | 228186700|          102.3|-4.5125665999999995|         48.370846|1459011600|    OUESSANT|6.0|
# | 234056000|            0.0|          -4.518463|         48.367275|1459011600|    OUESSANT|6.0|
# | 227009310|            3.8|         -4.5849366|48.281220000000005|1457168400|    OUESSANT|7.0|
# | 228186700|          102.3|          -4.512665|         48.370834|1457168400|    OUESSANT|7.0|
# | 228762000|            0.0|         -4.5067635|48.374615000000006|1457168400|    OUESSANT|7.0|
# | 227003050|           16.8| -4.805705000000001|         48.369408|1457168400|    OUESSANT|7.0|
# | 227574020|            0.0|         -4.4953585|48.383666999999996|1451638800|   BRIGNOGAN|5.0|
# | 228051000|            0.0|         -4.4845734|          48.38112|1451638800|   BRIGNOGAN|5.0|
# | 220540000|            0.3|          -4.330435|         48.118507|1451638800|   BRIGNOGAN|5.0|
# | 227904000|           10.2|         -4.5085983|         48.360374|1449795600|    OUESSANT|5.0|
# +----------+---------------+-------------------+------------------+----------+------------+---+
# only showing top 20 rows

# %%
map_r1 = map_r1.rdd

# %%
map_r1.getNumPartitions()
# Out:
# 8

# %%
map_r1.map(lambda x: tuple([x[0], (x[6])])).reduceByKey(max).collect()
# Out:
# [(228762000, 9.0),
#  (226178000, 9.0),
#  (228051000, 9.0),
#  (227580520, 9.0),
#  (226318000, 9.0),
#  (356071000, 7.0),
#  (228394000, 7.0),
#  (234056000, 9.0),
#  (220540000, 7.0),
#  (227904000, 6.0),
#  (226263000, 9.0),
#  (228041600, 7.0),
#  (228793000, 7.0),
#  (228336000, 7.0),
#  (227999400, 6.0),
#  (227142200, 7.0),
#  (249297000, 6.0),
#  (228109000, 7.0),
#  (314255000, 4.0),
#  (228796000, 6.0),
#  (311166000, 3.0),
#  (227941000, 8.0),
#  (227091000, 9.0),
#  (219124000, 7.0),
#  (259019000, 9.0),
#  (228032800, 7.0),
#  (245181000, 5.0),
#  (367852000, 4.0),
#  (227143600, 7.0),
#  (227148000, 6.0),
#  (228144000, 6.0),
#  (228293000, 5.0),
#  (314237000, 6.0),
#  (228208800, 7.0),
#  (228068600, 6.0),
#  (228150000, 5.0),
#  (249959000, 4.0),
#  (227392000, 8.0),
#  (228344800, 8.0),
#  (227019400, 6.0),
#  (304927000, 6.0),
#  (305600000, 7.0),
#  (228043800, 9.0),
#  (227485000, 2.0),
#  (227297000, 7.0),
#  (228240000, 4.0),
#  (226177000, 7.0),
#  (227577000, 6.0),
#  (227270000, 6.0),
#  (249616000, 6.0),
#  (227641920, 7.0),
#  (228236600, 9.0),
#  (226338000, 7.0),
#  (305886000, 5.0),
#  (218551000, 5.0),
#  (304088000, 9.0),
#  (351020000, 6.0),
#  (228874000, 3.0),
#  (227704000, 4.0),
#  (228228800, 9.0),
#  (518866000, 7.0),
#  (356101000, 7.0),
#  (246497000, 7.0),
#  (577228000, 5.0),
#  (227380000, 6.0),
#  (227393000, 9.0),
#  (227391000, 7.0),
#  (228736000, 7.0),
#  (227635680, 6.0),
#  (227573440, 5.0),
#  (356904000, 6.0),
#  (248465000, 6.0),
#  (374281000, 6.0),
#  (275346000, 4.0),
#  (271044120, 6.0),
#  (269669000, 6.0),
#  (227300000, 7.0),
#  (227311000, 5.0),
#  (227831000, 4.0),
#  (431156000, 7.0),
#  (226216000, 6.0),
#  (305709000, 2.0),
#  (228174600, 7.0),
#  (228799000, 4.0),
#  (228827000, 5.0),
#  (228160000, 7.0),
#  (305137000, 4.0),
#  (211707600, 7.0),
#  (308541000, 3.0),
#  (227330000, 7.0),
#  (228037600, 7.0),
#  (309165000, 7.0),
#  (227410000, 7.0),
#  (227860000, 6.0),
#  (226105000, 7.0),
#  (228791000, 7.0),
#  (304655000, 7.0),
#  (227146400, 5.0),
#  (304050840, 3.0),
#  (256765000, 7.0),
#  (304903000, 2.0),
#  (226267000, 6.0),
#  (220417000, 7.0),
#  (228130000, 6.0),
#  (228813000, 5.0),
#  (244772000, 3.0),
#  (249993000, 7.0),
#  (477820000, 7.0),
#  (276700000, 5.0),
#  (245334000, 3.0),
#  (227347000, 7.0),
#  (227436000, 6.0),
#  (664209000, 3.0),
#  (227397840, 6.0),
#  (228849000, 4.0),
#  (310556000, 5.0),
#  (311027800, 6.0),
#  (273376520, 8.0),
#  (256208000, 7.0),
#  (227867000, 6.0),
#  (211158080, 5.0),
#  (236213000, 6.0),
#  (565150000, 6.0),
#  (228157000, 6.0),
#  (246388000, 5.0),
#  (256494000, 7.0),
#  (245727000, 5.0),
#  (220497000, 5.0),
#  (227366000, 6.0),
#  (305166000, 5.0),
#  (228727000, 5.0),
#  (256462000, 5.0),
#  (256341000, 3.0),
#  (247224200, 5.0),
#  (244925000, 6.0),
#  (227690560, 6.0),
#  (235102352, 6.0),
#  (245127000, 5.0),
#  (538006224, 5.0),
#  (228059800, 6.0),
#  (211330520, 7.0),
#  (565494000, 6.0),
#  (226158000, 7.0),
#  (227590000, 6.0),
#  (236567000, 8.0),
#  (244469000, 7.0),
#  (228946000, 5.0),
#  (227406000, 6.0),
#  (228183600, 6.0),
#  (248363000, 3.0),
#  (477078200, 6.0),
#  (309225000, 7.0),
#  (378394000, 6.0),
#  (227589520, 5.0),
#  (477764600, 5.0),
#  (227397000, 2.0),
#  (256673000, 6.0),
#  (246457000, 5.0),
#  (256755000, 6.0),
#  (227314000, 5.0),
#  (308688000, 5.0),
#  (224389000, 6.0),
#  (246043000, 5.0),
#  (566422000, 5.0),
#  (246252000, 7.0),
#  (369886000, 5.0),
#  (230357000, 6.0),
#  (245839000, 6.0),
#  (244847000, 5.0),
#  (215901000, 5.0),
#  (245078000, 4.0),
#  (228919000, 6.0),
#  (255801480, 5.0),
#  (228035600, 4.0),
#  (228138000, 3.0),
#  (636014720, 3.0),
#  (228033600, 4.0),
#  (249104000, 5.0),
#  (564446000, 6.0),
#  (212542000, 3.0),
#  (306872000, 5.0),
#  (258316000, 6.0),
#  (227521960, 2.0),
#  (228205800, 4.0),
#  (228378000, 5.0),
#  (228111000, 5.0),
#  (311164000, 3.0),
#  (236509000, 6.0),
#  (227391760, 4.0),
#  (256483000, 6.0),
#  (227895000, 5.0),
#  (226179000, 5.0),
#  (311017800, 6.0),
#  (228858000, 6.0),
#  (228917000, 5.0),
#  (373570000, 4.0),
#  (205439000, 5.0),
#  (228797000, 5.0),
#  (636011640, 7.0),
#  (304060000, 5.0),
#  (577333000, 4.0),
#  (355028000, 5.0),
#  (227222000, 8.0),
#  (227988000, 5.0),
#  (566826000, 7.0),
#  (356615000, 6.0),
#  (228195000, 6.0),
#  (352216000, 6.0),
#  (227581000, 7.0),
#  (205204000, 6.0),
#  (253217000, 3.0),
#  (224384000, 2.0),
#  (212373000, 7.0),
#  (235101728, 6.0),
#  (244819000, 7.0),
#  (888888888, 6.0),
#  (212109000, 5.0),
#  (256838000, 1.0),
#  (228947000, 5.0),
#  (227532000, 4.0),
#  (227636480, 5.0),
#  (228168600, 7.0),
#  (235015064, 5.0),
#  (257739000, 2.0),
#  (228333000, 2.0),
#  (227336000, 5.0),
#  (305122000, 5.0),
#  (228355800, 3.0),
#  (227981000, 3.0),
#  (235050032, 1.0),
#  (227486000, 5.0),
#  (226084000, 7.0),
#  (220625000, 6.0),
#  (244543000, 3.0),
#  (228931000, 2.0),
#  (235103736, 6.0),
#  (314179000, 5.0),
#  (236222000, 5.0),
#  (249050000, 3.0),
#  (229898000, 7.0),
#  (220052000, 5.0),
#  (225371000, 2.0),
#  (228106800, 6.0),
#  (305685000, 5.0),
#  (211881000, 5.0),
#  (235437000, 6.0),
#  (244027000, 6.0),
#  (227309000, 5.0),
#  (224038000, 5.0),
#  (403531001, 4.0),
#  (636016457, 6.0),
#  (636015129, 9.0),
#  (636092361, 6.0),
#  (235087041, 8.0),
#  (235050609, 6.0),
#  (235108105, 5.0),
#  (636012377, 4.0),
#  (227003050, 9.0),
#  (227319570, 6.0),
#  (227008170, 8.0),
#  (304010986, 7.0),
#  (227635210, 9.0),
#  (227318010, 7.0),
#  (227002330, 7.0),
#  (227003850, 7.0),
#  (227696930, 5.0),
#  (538004506, 6.0),
#  (224067130, 6.0),
#  (227004410, 9.0),
#  (227588970, 5.0),
#  (227598930, 5.0),
#  (227597130, 5.0),
#  (636015106, 5.0),
#  (538003514, 3.0),
#  (227611930, 5.0),
#  (269101930, 5.0),
#  (227628730, 7.0),
#  (227029970, 4.0),
#  (227541490, 7.0),
#  (227666970, 5.0),
#  (538005218, 6.0),
#  (227635650, 3.0),
#  (227283010, 2.0),
#  (211617730, 5.0),
#  (227104210, 5.0),
#  (273334930, 5.0),
#  (244810418, 5.0),
#  (235101211, 7.0),
#  (244810323, 6.0),
#  (636016595, 7.0),
#  (227592820, 7.0),
#  (228064900, 9.0),
#  (228186700, 10.0),
#  (227574020, 8.0),
#  (227306100, 5.0),
#  (228155700, 6.0),
#  (228017700, 9.0),
#  (227612860, 8.0),
#  (227114300, 7.0),
#  (311009700, 5.0),
#  (228208700, 5.0),
#  (228292700, 6.0),
#  (227578460, 5.0),
#  (227730220, 8.0),
#  (228299900, 6.0),
#  (228015700, 9.0),
#  (227590980, 7.0),
#  (228213700, 7.0),
#  (228302900, 6.0),
#  (228137900, 5.0),
#  (227312180, 5.0),
#  (227185540, 4.0),
#  (228037700, 7.0),
#  (227016100, 7.0),
#  (228037900, 4.0),
#  (227806500, 6.0),
#  (228236700, 6.0),
#  (227686540, 6.0),
#  (228267700, 5.0),
#  (228215700, 5.0),
#  (228218700, 6.0),
#  (227639660, 7.0),
#  (227569380, 5.0),
#  (228167900, 7.0),
#  (227762340, 4.0),
#  (311027900, 6.0),
#  (230941700, 7.0),
#  (227736540, 7.0),
#  (227715260, 6.0),
#  (228156900, 5.0),
#  (228238700, 7.0),
#  (228817100, 7.0),
#  (227113100, 3.0),
#  (227109900, 4.0),
#  (227621940, 5.0),
#  (273322500, 5.0),
#  (228267900, 8.0),
#  (211211220, 3.0),
#  (228020900, 5.0),
#  (228020700, 8.0),
#  (227320660, 8.0),
#  (211552340, 7.0),
#  (227318020, 7.0),
#  (228234900, 4.0),
#  (227145700, 6.0),
#  (227177420, 3.0),
#  (538004772, 4.0),
#  (228022900, 3.0),
#  (235006740, 7.0),
#  (227654220, 7.0),
#  (228160900, 6.0),
#  (228211700, 7.0),
#  (227641020, 1.0),
#  (255802940, 4.0),
#  (235075244, 5.0),
#  (636016436, 4.0),
#  (228005700, 6.0),
#  (228151700, 4.0),
#  (227144300, 4.0),
#  (311018500, 5.0),
#  (228301900, 5.0),
#  (538002973, 7.0),
#  (235106917, 6.0),
#  (636091933, 7.0),
#  (235098061, 5.0),
#  (255805693, 3.0),
#  (636016149, 6.0),
#  (235081933, 5.0),
#  (227009310, 8.0),
#  (227705102, 9.0),
#  (227362110, 6.0),
#  (227005550, 7.0),
#  (227640710, 5.0),
#  (227163870, 5.0),
#  (227754790, 5.0),
#  (227002630, 8.0),
#  (235113366, 3.0),
#  (227632830, 6.0),
#  (235005150, 6.0),
#  (227315110, 6.0),
#  (227590030, 4.0),
#  (224005190, 8.0),
#  (227006750, 9.0),
#  (227278350, 5.0),
#  (227702670, 7.0),
#  (227640190, 4.0),
#  (227303430, 8.0),
#  (227650230, 6.0),
#  (227400510, 7.0),
#  (227408710, 3.0),
#  (227009430, 5.0),
#  (227004390, 5.0),
#  (227310150, 2.0),
#  (211160630, 3.0),
#  (255805694, 6.0),
#  (227536950, 3.0),
#  (227169310, 4.0),
#  (227280910, 2.0),
#  (227217470, 4.0),
#  (227298110, 2.0),
#  (227322670, 4.0),
#  (227069470, 5.0),
#  (227681710, 5.0),
#  (227591030, 3.0),
#  (227394750, 2.0),
#  (999999999, 7.0),
#  (636092263, 5.0),
#  (235114599, 6.0),
#  (235096647, 6.0)]

# %%
map_r1.map(lambda x: tuple([x[0], (x[6])])).reduceByKey(min).collect()
# Out:
# [(228762000, 0.0),
#  (226178000, 0.0),
#  (228051000, 2.0),
#  (227580520, 2.0),
#  (226318000, 2.0),
#  (356071000, 2.0),
#  (228394000, 2.0),
#  (234056000, 1.0),
#  (220540000, 3.0),
#  (227904000, 2.0),
#  (226263000, 2.0),
#  (228041600, 2.0),
#  (228793000, 2.0),
#  (228336000, 2.0),
#  (227999400, 3.0),
#  (227142200, 2.0),
#  (249297000, 2.0),
#  (228109000, 0.0),
#  (314255000, 4.0),
#  (228796000, 3.0),
#  (311166000, 2.0),
#  (227941000, 1.0),
#  (227091000, 2.0),
#  (219124000, 5.0),
#  (259019000, 0.0),
#  (228032800, 3.0),
#  (245181000, 0.0),
#  (367852000, 3.0),
#  (227143600, 3.0),
#  (227148000, 3.0),
#  (228144000, 2.0),
#  (228293000, 2.0),
#  (314237000, 5.0),
#  (228208800, 2.0),
#  (228068600, 2.0),
#  (228150000, 4.0),
#  (249959000, 4.0),
#  (227392000, 2.0),
#  (228344800, 2.0),
#  (227019400, 2.0),
#  (304927000, 6.0),
#  (305600000, 3.0),
#  (228043800, 2.0),
#  (227485000, 2.0),
#  (227297000, 0.0),
#  (228240000, 4.0),
#  (226177000, 2.0),
#  (227577000, 2.0),
#  (227270000, 2.0),
#  (249616000, 6.0),
#  (227641920, 2.0),
#  (228236600, 6.0),
#  (226338000, 3.0),
#  (305886000, 2.0),
#  (218551000, 5.0),
#  (304088000, 5.0),
#  (351020000, 2.0),
#  (228874000, 3.0),
#  (227704000, 4.0),
#  (228228800, 3.0),
#  (518866000, 4.0),
#  (356101000, 3.0),
#  (246497000, 2.0),
#  (577228000, 4.0),
#  (227380000, 3.0),
#  (227393000, 5.0),
#  (227391000, 1.0),
#  (228736000, 2.0),
#  (227635680, 2.0),
#  (227573440, 4.0),
#  (356904000, 3.0),
#  (248465000, 6.0),
#  (374281000, 5.0),
#  (275346000, 4.0),
#  (271044120, 6.0),
#  (269669000, 5.0),
#  (227300000, 1.0),
#  (227311000, 5.0),
#  (227831000, 4.0),
#  (431156000, 7.0),
#  (226216000, 2.0),
#  (305709000, 2.0),
#  (228174600, 4.0),
#  (228799000, 3.0),
#  (228827000, 2.0),
#  (228160000, 2.0),
#  (305137000, 4.0),
#  (211707600, 3.0),
#  (308541000, 3.0),
#  (227330000, 6.0),
#  (228037600, 2.0),
#  (309165000, 4.0),
#  (227410000, 4.0),
#  (227860000, 4.0),
#  (226105000, 4.0),
#  (228791000, 0.0),
#  (304655000, 6.0),
#  (227146400, 3.0),
#  (304050840, 3.0),
#  (256765000, 3.0),
#  (304903000, 2.0),
#  (226267000, 6.0),
#  (220417000, 4.0),
#  (228130000, 4.0),
#  (228813000, 3.0),
#  (244772000, 3.0),
#  (249993000, 3.0),
#  (477820000, 5.0),
#  (276700000, 3.0),
#  (245334000, 3.0),
#  (227347000, 6.0),
#  (227436000, 4.0),
#  (664209000, 3.0),
#  (227397840, 6.0),
#  (228849000, 4.0),
#  (310556000, 5.0),
#  (311027800, 5.0),
#  (273376520, 5.0),
#  (256208000, 6.0),
#  (227867000, 3.0),
#  (211158080, 4.0),
#  (236213000, 5.0),
#  (565150000, 5.0),
#  (228157000, 5.0),
#  (246388000, 3.0),
#  (256494000, 3.0),
#  (245727000, 5.0),
#  (220497000, 5.0),
#  (227366000, 4.0),
#  (305166000, 5.0),
#  (228727000, 4.0),
#  (256462000, 4.0),
#  (256341000, 3.0),
#  (247224200, 5.0),
#  (244925000, 6.0),
#  (227690560, 5.0),
#  (235102352, 5.0),
#  (245127000, 5.0),
#  (538006224, 3.0),
#  (228059800, 3.0),
#  (211330520, 6.0),
#  (565494000, 6.0),
#  (226158000, 4.0),
#  (227590000, 5.0),
#  (236567000, 8.0),
#  (244469000, 7.0),
#  (228946000, 3.0),
#  (227406000, 6.0),
#  (228183600, 4.0),
#  (248363000, 3.0),
#  (477078200, 6.0),
#  (309225000, 7.0),
#  (378394000, 6.0),
#  (227589520, 3.0),
#  (477764600, 5.0),
#  (227397000, 2.0),
#  (256673000, 5.0),
#  (246457000, 5.0),
#  (256755000, 5.0),
#  (227314000, 3.0),
#  (308688000, 5.0),
#  (224389000, 6.0),
#  (246043000, 4.0),
#  (566422000, 5.0),
#  (246252000, 7.0),
#  (369886000, 4.0),
#  (230357000, 6.0),
#  (245839000, 6.0),
#  (244847000, 4.0),
#  (215901000, 4.0),
#  (245078000, 4.0),
#  (228919000, 5.0),
#  (255801480, 5.0),
#  (228035600, 4.0),
#  (228138000, 3.0),
#  (636014720, 3.0),
#  (228033600, 4.0),
#  (249104000, 5.0),
#  (564446000, 6.0),
#  (212542000, 3.0),
#  (306872000, 5.0),
#  (258316000, 6.0),
#  (227521960, 2.0),
#  (228205800, 4.0),
#  (228378000, 5.0),
#  (228111000, 5.0),
#  (311164000, 2.0),
#  (236509000, 6.0),
#  (227391760, 4.0),
#  (256483000, 6.0),
#  (227895000, 5.0),
#  (226179000, 3.0),
#  (311017800, 6.0),
#  (228858000, 6.0),
#  (228917000, 3.0),
#  (373570000, 1.0),
#  (205439000, 5.0),
#  (228797000, 3.0),
#  (636011640, 7.0),
#  (304060000, 4.0),
#  (577333000, 4.0),
#  (355028000, 5.0),
#  (227222000, 7.0),
#  (227988000, 2.0),
#  (566826000, 7.0),
#  (356615000, 6.0),
#  (228195000, 6.0),
#  (352216000, 6.0),
#  (227581000, 6.0),
#  (205204000, 5.0),
#  (253217000, 3.0),
#  (224384000, 2.0),
#  (212373000, 6.0),
#  (235101728, 6.0),
#  (244819000, 6.0),
#  (888888888, 6.0),
#  (212109000, 5.0),
#  (256838000, 1.0),
#  (228947000, 5.0),
#  (227532000, 4.0),
#  (227636480, 2.0),
#  (228168600, 7.0),
#  (235015064, 5.0),
#  (257739000, 2.0),
#  (228333000, 2.0),
#  (227336000, 5.0),
#  (305122000, 5.0),
#  (228355800, 3.0),
#  (227981000, 3.0),
#  (235050032, 1.0),
#  (227486000, 5.0),
#  (226084000, 3.0),
#  (220625000, 5.0),
#  (244543000, 2.0),
#  (228931000, 2.0),
#  (235103736, 6.0),
#  (314179000, 5.0),
#  (236222000, 5.0),
#  (249050000, 3.0),
#  (229898000, 7.0),
#  (220052000, 5.0),
#  (225371000, 2.0),
#  (228106800, 6.0),
#  (305685000, 5.0),
#  (211881000, 5.0),
#  (235437000, 6.0),
#  (244027000, 6.0),
#  (227309000, 5.0),
#  (224038000, 5.0),
#  (403531001, 3.0),
#  (636016457, 6.0),
#  (636015129, 8.0),
#  (636092361, 5.0),
#  (235087041, 2.0),
#  (235050609, 6.0),
#  (235108105, 5.0),
#  (636012377, 4.0),
#  (227003050, 2.0),
#  (227319570, 2.0),
#  (227008170, 2.0),
#  (304010986, 6.0),
#  (227635210, 2.0),
#  (227318010, 2.0),
#  (227002330, 2.0),
#  (227003850, 2.0),
#  (227696930, 4.0),
#  (538004506, 6.0),
#  (224067130, 6.0),
#  (227004410, 5.0),
#  (227588970, 5.0),
#  (227598930, 4.0),
#  (227597130, 3.0),
#  (636015106, 4.0),
#  (538003514, 3.0),
#  (227611930, 3.0),
#  (269101930, 5.0),
#  (227628730, 5.0),
#  (227029970, 1.0),
#  (227541490, 7.0),
#  (227666970, 5.0),
#  (538005218, 6.0),
#  (227635650, 3.0),
#  (227283010, 2.0),
#  (211617730, 4.0),
#  (227104210, 5.0),
#  (273334930, 5.0),
#  (244810418, 5.0),
#  (235101211, 4.0),
#  (244810323, 6.0),
#  (636016595, 7.0),
#  (227592820, 2.0),
#  (228064900, 2.0),
#  (228186700, 2.0),
#  (227574020, 1.0),
#  (227306100, 1.0),
#  (228155700, 3.0),
#  (228017700, 2.0),
#  (227612860, 1.0),
#  (227114300, 3.0),
#  (311009700, 5.0),
#  (228208700, 2.0),
#  (228292700, 1.0),
#  (227578460, 3.0),
#  (227730220, 2.0),
#  (228299900, 6.0),
#  (228015700, 4.0),
#  (227590980, 2.0),
#  (228213700, 3.0),
#  (228302900, 2.0),
#  (228137900, 5.0),
#  (227312180, 4.0),
#  (227185540, 3.0),
#  (228037700, 2.0),
#  (227016100, 1.0),
#  (228037900, 1.0),
#  (227806500, 2.0),
#  (228236700, 5.0),
#  (227686540, 2.0),
#  (228267700, 3.0),
#  (228215700, 5.0),
#  (228218700, 2.0),
#  (227639660, 5.0),
#  (227569380, 3.0),
#  (228167900, 2.0),
#  (227762340, 2.0),
#  (311027900, 6.0),
#  (230941700, 2.0),
#  (227736540, 3.0),
#  (227715260, 6.0),
#  (228156900, 5.0),
#  (228238700, 5.0),
#  (228817100, 5.0),
#  (227113100, 3.0),
#  (227109900, 4.0),
#  (227621940, 4.0),
#  (273322500, 4.0),
#  (228267900, 8.0),
#  (211211220, 2.0),
#  (228020900, 4.0),
#  (228020700, 4.0),
#  (227320660, 7.0),
#  (211552340, 7.0),
#  (227318020, 2.0),
#  (228234900, 4.0),
#  (227145700, 4.0),
#  (227177420, 3.0),
#  (538004772, 4.0),
#  (228022900, 3.0),
#  (235006740, 7.0),
#  (227654220, 4.0),
#  (228160900, 5.0),
#  (228211700, 7.0),
#  (227641020, 1.0),
#  (255802940, 4.0),
#  (235075244, 5.0),
#  (636016436, 4.0),
#  (228005700, 6.0),
#  (228151700, 4.0),
#  (227144300, 4.0),
#  (311018500, 5.0),
#  (228301900, 5.0),
#  (538002973, 3.0),
#  (235106917, 2.0),
#  (636091933, 5.0),
#  (235098061, 4.0),
#  (255805693, 3.0),
#  (636016149, 6.0),
#  (235081933, 5.0),
#  (227009310, 3.0),
#  (227705102, 1.0),
#  (227362110, 2.0),
#  (227005550, 0.0),
#  (227640710, 1.0),
#  (227163870, 5.0),
#  (227754790, 5.0),
#  (227002630, 2.0),
#  (235113366, 3.0),
#  (227632830, 4.0),
#  (235005150, 5.0),
#  (227315110, 4.0),
#  (227590030, 2.0),
#  (224005190, 3.0),
#  (227006750, 3.0),
#  (227278350, 4.0),
#  (227702670, 6.0),
#  (227640190, 4.0),
#  (227303430, 3.0),
#  (227650230, 2.0),
#  (227400510, 5.0),
#  (227408710, 3.0),
#  (227009430, 5.0),
#  (227004390, 5.0),
#  (227310150, 2.0),
#  (211160630, 3.0),
#  (255805694, 6.0),
#  (227536950, 3.0),
#  (227169310, 4.0),
#  (227280910, 2.0),
#  (227217470, 4.0),
#  (227298110, 2.0),
#  (227322670, 4.0),
#  (227069470, 5.0),
#  (227681710, 5.0),
#  (227591030, 3.0),
#  (227394750, 2.0),
#  (999999999, 2.0),
#  (636092263, 5.0),
#  (235114599, 6.0),
#  (235096647, 6.0)]

# %%
map_r1.map(lambda x: tuple([x[0]])).countByKey()
# Out:
# defaultdict(int,
#             {227592820: 15,
#              228762000: 209,
#              226178000: 66,
#              228051000: 417,
#              227580520: 230,
#              226318000: 45,
#              356071000: 22,
#              228394000: 27,
#              228064900: 38,
#              228186700: 307,
#              234056000: 209,
#              227009310: 16,
#              227003050: 198,
#              227574020: 288,
#              220540000: 11,
#              227904000: 7,
#              226263000: 84,
#              228041600: 14,
#              227306100: 16,
#              227319570: 8,
#              228793000: 13,
#              228336000: 45,
#              227999400: 21,
#              227705102: 231,
#              227142200: 24,
#              228155700: 3,
#              249297000: 14,
#              228109000: 75,
#              314255000: 1,
#              228796000: 3,
#              227362110: 10,
#              227005550: 21,
#              311166000: 2,
#              227941000: 171,
#              227091000: 24,
#              227008170: 56,
#              227640710: 5,
#              219124000: 3,
#              228017700: 105,
#              259019000: 49,
#              228032800: 12,
#              304010986: 4,
#              227612860: 33,
#              245181000: 5,
#              227114300: 10,
#              367852000: 2,
#              227143600: 10,
#              227148000: 23,
#              228144000: 16,
#              228293000: 19,
#              314237000: 4,
#              228208800: 20,
#              311009700: 1,
#              538002973: 38,
#              228208700: 3,
#              228068600: 15,
#              228150000: 2,
#              999999999: 55,
#              227163870: 1,
#              249959000: 1,
#              227392000: 19,
#              228344800: 71,
#              227019400: 34,
#              228292700: 9,
#              304927000: 1,
#              227578460: 6,
#              227730220: 52,
#              305600000: 15,
#              227754790: 1,
#              228299900: 1,
#              227002630: 39,
#              228015700: 27,
#              228043800: 4,
#              227485000: 2,
#              227635210: 124,
#              227297000: 18,
#              228240000: 1,
#              226177000: 19,
#              227577000: 11,
#              235113366: 4,
#              227318010: 29,
#              227002330: 8,
#              227590980: 10,
#              228213700: 10,
#              227632830: 3,
#              228302900: 7,
#              227270000: 9,
#              228137900: 1,
#              235005150: 2,
#              227315110: 4,
#              227590030: 3,
#              249616000: 1,
#              227641920: 4,
#              228236600: 12,
#              226338000: 13,
#              305886000: 4,
#              218551000: 1,
#              304088000: 6,
#              351020000: 10,
#              235106917: 2,
#              228874000: 1,
#              227704000: 3,
#              228228800: 7,
#              518866000: 9,
#              227312180: 3,
#              403531001: 3,
#              356101000: 23,
#              246497000: 18,
#              577228000: 6,
#              227380000: 14,
#              227393000: 3,
#              227391000: 37,
#              224005190: 3,
#              228736000: 27,
#              227185540: 2,
#              227635680: 11,
#              228037700: 18,
#              227573440: 3,
#              227016100: 20,
#              356904000: 6,
#              228037900: 16,
#              636016457: 2,
#              227006750: 16,
#              248465000: 1,
#              227278350: 4,
#              636092263: 1,
#              374281000: 4,
#              275346000: 2,
#              235101211: 7,
#              271044120: 2,
#              269669000: 3,
#              227003850: 5,
#              227300000: 21,
#              227696930: 3,
#              227806500: 5,
#              227702670: 3,
#              227311000: 1,
#              227831000: 3,
#              431156000: 1,
#              226216000: 7,
#              305709000: 2,
#              228174600: 8,
#              228799000: 12,
#              228827000: 5,
#              228160000: 19,
#              305137000: 1,
#              211707600: 5,
#              228236700: 8,
#              308541000: 1,
#              227330000: 3,
#              228037600: 23,
#              309165000: 5,
#              538004506: 3,
#              227640190: 2,
#              227686540: 6,
#              227410000: 3,
#              227860000: 2,
#              226105000: 4,
#              228267700: 12,
#              636091933: 3,
#              228791000: 6,
#              228215700: 2,
#              304655000: 4,
#              227146400: 8,
#              304050840: 1,
#              228218700: 7,
#              636015129: 3,
#              256765000: 2,
#              304903000: 2,
#              226267000: 2,
#              227639660: 3,
#              220417000: 2,
#              227569380: 2,
#              228167900: 10,
#              224067130: 1,
#              228130000: 4,
#              228813000: 6,
#              244772000: 1,
#              227762340: 2,
#              249993000: 4,
#              477820000: 7,
#              227303430: 9,
#              276700000: 3,
#              245334000: 2,
#              227347000: 2,
#              311027900: 1,
#              227004410: 2,
#              230941700: 4,
#              227436000: 3,
#              227650230: 7,
#              664209000: 1,
#              227397840: 1,
#              228849000: 1,
#              310556000: 3,
#              227736540: 5,
#              311027800: 3,
#              273376520: 8,
#              256208000: 2,
#              227867000: 4,
#              211158080: 3,
#              227715260: 1,
#              236213000: 2,
#              565150000: 3,
#              228157000: 3,
#              227400510: 2,
#              246388000: 7,
#              256494000: 12,
#              227408710: 1,
#              227588970: 2,
#              228156900: 5,
#              245727000: 2,
#              227598930: 2,
#              220497000: 1,
#              227009430: 1,
#              227366000: 4,
#              305166000: 1,
#              228727000: 4,
#              256462000: 2,
#              256341000: 1,
#              228238700: 3,
#              228817100: 2,
#              227113100: 2,
#              247224200: 1,
#              227109900: 1,
#              227621940: 3,
#              244925000: 2,
#              227690560: 3,
#              235102352: 2,
#              273322500: 5,
#              245127000: 1,
#              235114599: 2,
#              538006224: 2,
#              228267900: 2,
#              211211220: 3,
#              228059800: 5,
#              211330520: 2,
#              565494000: 1,
#              226158000: 4,
#              227590000: 2,
#              236567000: 1,
#              227597130: 2,
#              244469000: 2,
#              228946000: 2,
#              227406000: 2,
#              228183600: 7,
#              248363000: 3,
#              636015106: 2,
#              477078200: 1,
#              309225000: 1,
#              235098061: 3,
#              378394000: 1,
#              227589520: 2,
#              244810323: 1,
#              636092361: 2,
#              477764600: 1,
#              227397000: 1,
#              256673000: 2,
#              246457000: 1,
#              538003514: 1,
#              227611930: 5,
#              256755000: 2,
#              227314000: 2,
#              308688000: 1,
#              224389000: 1,
#              246043000: 2,
#              228020900: 2,
#              228020700: 5,
#              566422000: 1,
#              246252000: 1,
#              227320660: 2,
#              227004390: 1,
#              369886000: 2,
#              211552340: 2,
#              227310150: 1,
#              230357000: 1,
#              245839000: 1,
#              244847000: 3,
#              215901000: 2,
#              245078000: 1,
#              228919000: 3,
#              211160630: 2,
#              235087041: 3,
#              255801480: 2,
#              228035600: 1,
#              227318020: 12,
#              228138000: 2,
#              636014720: 1,
#              228033600: 1,
#              228234900: 1,
#              249104000: 3,
#              564446000: 1,
#              235096647: 1,
#              255805693: 1,
#              212542000: 1,
#              306872000: 1,
#              235050609: 2,
#              258316000: 1,
#              227521960: 3,
#              269101930: 1,
#              227145700: 2,
#              228205800: 1,
#              228378000: 1,
#              228111000: 1,
#              311164000: 2,
#              236509000: 1,
#              255805694: 1,
#              227391760: 1,
#              227177420: 1,
#              227536950: 1,
#              256483000: 1,
#              227895000: 2,
#              226179000: 4,
#              538004772: 1,
#              227169310: 1,
#              227628730: 3,
#              311017800: 1,
#              228858000: 1,
#              227029970: 2,
#              636016149: 1,
#              228917000: 3,
#              373570000: 3,
#              205439000: 1,
#              228797000: 3,
#              636011640: 1,
#              304060000: 3,
#              227541490: 1,
#              577333000: 1,
#              227280910: 1,
#              355028000: 1,
#              227222000: 3,
#              228022900: 1,
#              227988000: 2,
#              566826000: 1,
#              356615000: 1,
#              228195000: 1,
#              352216000: 1,
#              227581000: 2,
#              205204000: 2,
#              235006740: 1,
#              227654220: 2,
#              253217000: 1,
#              224384000: 1,
#              228160900: 2,
#              228211700: 1,
#              227666970: 1,
#              212373000: 2,
#              227217470: 1,
#              235101728: 1,
#              538005218: 1,
#              227641020: 1,
#              244819000: 3,
#              888888888: 1,
#              255802940: 1,
#              227298110: 1,
#              212109000: 1,
#              235075244: 1,
#              256838000: 1,
#              228947000: 2,
#              227532000: 1,
#              636016436: 1,
#              227636480: 2,
#              227635650: 1,
#              228168600: 1,
#              235015064: 1,
#              257739000: 1,
#              228333000: 1,
#              227322670: 1,
#              227069470: 1,
#              227336000: 1,
#              305122000: 1,
#              228355800: 1,
#              228005700: 1,
#              227981000: 1,
#              235050032: 1,
#              235108105: 1,
#              227283010: 1,
#              227486000: 1,
#              226084000: 2,
#              235081933: 1,
#              220625000: 2,
#              227681710: 1,
#              244543000: 2,
#              211617730: 2,
#              228151700: 1,
#              636012377: 1,
#              227104210: 1,
#              228931000: 1,
#              235103736: 1,
#              636016595: 1,
#              314179000: 1,
#              273334930: 1,
#              236222000: 1,
#              249050000: 1,
#              227591030: 1,
#              227394750: 1,
#              229898000: 1,
#              220052000: 1,
#              225371000: 1,
#              227144300: 1,
#              311018500: 1,
#              228106800: 1,
#              305685000: 1,
#              211881000: 1,
#              244810418: 1,
#              235437000: 1,
#              244027000: 1,
#              227309000: 1,
#              228301900: 1,
#              224038000: 1})

# %%
teliko_pred=teliko_pred.loc[teliko_pred['sourcemmsi']==228051000]

# %%
teliko_pred.drop(['sourcemmsi','lon','lat','station_name'],axis = 1, inplace=True)

# %%
pd.DataFrame(teliko_pred)
# Out:
#          speedoverground           t   Ff
# 6457456              0.0  1450598400  3.0
# 7092209              0.0  1451638800  5.0
# 6619363              0.0  1450836000  5.0
# 5381644              0.0  1449230400  3.0
# 6886940              0.0  1451311200  5.0
# ...                  ...         ...  ...
# 3178036              0.0  1447002000  5.0
# 4177828              0.4  1448042400  6.0
# 6688401              0.1  1450926000  4.0
# 6938257              0.0  1451401200  4.0
# 5615943              0.0  1449558000  3.0
#
# [417 rows x 3 columns]

# %%
map_r2 = spark.createDataFrame(teliko_pred)

# %%
map_r2.show()
# Out:
# +---------------+----------+---+
# |speedoverground|         t| Ff|
# +---------------+----------+---+
# |            0.0|1450598400|3.0|
# |            0.0|1451638800|5.0|
# |            0.0|1450836000|5.0|
# |            0.0|1449230400|3.0|
# |            0.0|1451311200|5.0|
# |            0.1|1448665200|7.0|
# |            0.0|1455235200|4.0|
# |            0.8|1448902800|5.0|
# |            0.0|1449140400|4.0|
# |            0.0|1448337600|3.0|
# |            0.0|1447534800|5.0|
# |            0.0|1450893600|3.0|
# |            0.0|1447207200|2.0|
# |            0.0|1448247600|4.0|
# |            0.1|1451131200|4.0|
# |            0.0|1447444800|6.0|
# |            0.0|1448722800|5.0|
# |            0.0|1455530400|5.0|
# |            0.0|1459454400|4.0|
# |            0.0|1452081600|5.0|
# +---------------+----------+---+
# only showing top 20 rows

# %%
from pyspark.sql import Row
from pyspark.ml.linalg import Vectors
def transData(data):
    return data.rdd.map(lambda r: [Vectors.dense(r[:-1]),r[-1]]).toDF(['features','label'])

# %%
transformed = transData(map_r2)
transformed.show()
# Out:
# +-----------------+-----+
# |         features|label|
# +-----------------+-----+
# |[0.0,1.4505984E9]|  3.0|
# |[0.0,1.4516388E9]|  5.0|
# | [0.0,1.450836E9]|  5.0|
# |[0.0,1.4492304E9]|  3.0|
# |[0.0,1.4513112E9]|  5.0|
# |[0.1,1.4486652E9]|  7.0|
# |[0.0,1.4552352E9]|  4.0|
# |[0.8,1.4489028E9]|  5.0|
# |[0.0,1.4491404E9]|  4.0|
# |[0.0,1.4483376E9]|  3.0|
# |[0.0,1.4475348E9]|  5.0|
# |[0.0,1.4508936E9]|  3.0|
# |[0.0,1.4472072E9]|  2.0|
# |[0.0,1.4482476E9]|  4.0|
# |[0.1,1.4511312E9]|  4.0|
# |[0.0,1.4474448E9]|  6.0|
# |[0.0,1.4487228E9]|  5.0|
# |[0.0,1.4555304E9]|  5.0|
# |[0.0,1.4594544E9]|  4.0|
# |[0.0,1.4520816E9]|  5.0|
# +-----------------+-----+
# only showing top 20 rows

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorIndexer
featureIndexer = VectorIndexer(inputCol="features", \
                               outputCol="indexedFeatures",\
                               maxCategories=4).fit(transformed)

data = featureIndexer.transform(transformed)

# %%
data.show()
# Out:
# +-----------------+-----+-----------------+
# |         features|label|  indexedFeatures|
# +-----------------+-----+-----------------+
# |[0.0,1.4505984E9]|  3.0|[0.0,1.4505984E9]|
# |[0.0,1.4516388E9]|  5.0|[0.0,1.4516388E9]|
# | [0.0,1.450836E9]|  5.0| [0.0,1.450836E9]|
# |[0.0,1.4492304E9]|  3.0|[0.0,1.4492304E9]|
# |[0.0,1.4513112E9]|  5.0|[0.0,1.4513112E9]|
# |[0.1,1.4486652E9]|  7.0|[0.1,1.4486652E9]|
# |[0.0,1.4552352E9]|  4.0|[0.0,1.4552352E9]|
# |[0.8,1.4489028E9]|  5.0|[0.8,1.4489028E9]|
# |[0.0,1.4491404E9]|  4.0|[0.0,1.4491404E9]|
# |[0.0,1.4483376E9]|  3.0|[0.0,1.4483376E9]|
# |[0.0,1.4475348E9]|  5.0|[0.0,1.4475348E9]|
# |[0.0,1.4508936E9]|  3.0|[0.0,1.4508936E9]|
# |[0.0,1.4472072E9]|  2.0|[0.0,1.4472072E9]|
# |[0.0,1.4482476E9]|  4.0|[0.0,1.4482476E9]|
# |[0.1,1.4511312E9]|  4.0|[0.1,1.4511312E9]|
# |[0.0,1.4474448E9]|  6.0|[0.0,1.4474448E9]|
# |[0.0,1.4487228E9]|  5.0|[0.0,1.4487228E9]|
# |[0.0,1.4555304E9]|  5.0|[0.0,1.4555304E9]|
# |[0.0,1.4594544E9]|  4.0|[0.0,1.4594544E9]|
# |[0.0,1.4520816E9]|  5.0|[0.0,1.4520816E9]|
# +-----------------+-----+-----------------+
# only showing top 20 rows

# %%
(trainingData, testData) = data.randomSplit([0.6, 0.4])

# %%
trainingData.show()
testData.show()
# Out:
# +-----------------+-----+-----------------+
# |         features|label|  indexedFeatures|
# +-----------------+-----+-----------------+
# |[0.0,1.4472072E9]|  2.0|[0.0,1.4472072E9]|
# |[0.0,1.4474448E9]|  6.0|[0.0,1.4474448E9]|
# |[0.0,1.4475348E9]|  5.0|[0.0,1.4475348E9]|
# |[0.0,1.4477976E9]|  5.0|[0.0,1.4477976E9]|
# |[0.0,1.4482728E9]|  2.0|[0.0,1.4482728E9]|
# |[0.0,1.4483376E9]|  3.0|[0.0,1.4483376E9]|
# |[0.0,1.4487228E9]|  5.0|[0.0,1.4487228E9]|
# |[0.0,1.4487804E9]|  6.0|[0.0,1.4487804E9]|
# | [0.0,1.448928E9]|  5.0| [0.0,1.448928E9]|
# | [0.0,1.449018E9]|  3.0| [0.0,1.449018E9]|
# |[0.0,1.4492304E9]|  3.0|[0.0,1.4492304E9]|
# |[0.0,1.4493456E9]|  4.0|[0.0,1.4493456E9]|
# |[0.0,1.4494032E9]|  5.0|[0.0,1.4494032E9]|
# |[0.0,1.4495508E9]|  4.0|[0.0,1.4495508E9]|
# |[0.0,1.4495832E9]|  5.0|[0.0,1.4495832E9]|
# | [0.0,1.450836E9]|  5.0| [0.0,1.450836E9]|
# |[0.0,1.4508936E9]|  3.0|[0.0,1.4508936E9]|
# |[0.0,1.4509188E9]|  4.0|[0.0,1.4509188E9]|
# |[0.0,1.4511564E9]|  4.0|[0.0,1.4511564E9]|
# |[0.0,1.4513364E9]|  4.0|[0.0,1.4513364E9]|
# +-----------------+-----+-----------------+
# only showing top 20 rows
#
# +-----------------+-----+-----------------+
# |         features|label|  indexedFeatures|
# +-----------------+-----+-----------------+
# |[0.0,1.4471748E9]|  3.0|[0.0,1.4471748E9]|
# |[0.0,1.4479776E9]|  5.0|[0.0,1.4479776E9]|
# |[0.0,1.4482476E9]|  4.0|[0.0,1.4482476E9]|
# |[0.0,1.4486904E9]|  6.0|[0.0,1.4486904E9]|
# |[0.0,1.4491404E9]|  4.0|[0.0,1.4491404E9]|
# |[0.0,1.4494356E9]|  3.0|[0.0,1.4494356E9]|
# |[0.0,1.4494932E9]|  5.0|[0.0,1.4494932E9]|
# |[0.0,1.4505984E9]|  3.0|[0.0,1.4505984E9]|
# |[0.0,1.4508612E9]|  3.0|[0.0,1.4508612E9]|
# |[0.0,1.4513112E9]|  5.0|[0.0,1.4513112E9]|
# | [0.0,1.451574E9]|  4.0| [0.0,1.451574E9]|
# |[0.0,1.4516316E9]|  4.0|[0.0,1.4516316E9]|
# |[0.0,1.4520816E9]|  5.0|[0.0,1.4520816E9]|
# |[0.0,1.4552352E9]|  4.0|[0.0,1.4552352E9]|
# |[0.0,1.4554404E9]|  6.0|[0.0,1.4554404E9]|
# | [0.0,1.455498E9]|  7.0| [0.0,1.455498E9]|
# |[0.0,1.4555304E9]|  5.0|[0.0,1.4555304E9]|
# | [0.0,1.459332E9]|  2.0| [0.0,1.459332E9]|
# | [0.0,1.459422E9]|  4.0| [0.0,1.459422E9]|
# |[0.1,1.4515164E9]|  6.0|[0.1,1.4515164E9]|
# +-----------------+-----+-----------------+
# only showing top 20 rows

# %%
from pyspark.ml.regression import DecisionTreeRegressor

dt = DecisionTreeRegressor(featuresCol="indexedFeatures")

# %%
pipeline = Pipeline(stages=[featureIndexer, dt])

model = pipeline.fit(trainingData)

# %%
predictions = model.transform(testData)

# %%
predictions.show(predictions.count(), False)
# Out:
# +-----------------+-----+-----------------+-----------------+
# |features         |label|indexedFeatures  |prediction       |
# +-----------------+-----+-----------------+-----------------+
# |[0.0,1.4471748E9]|3.0  |[0.0,1.4471748E9]|3.2              |
# |[0.0,1.4479776E9]|5.0  |[0.0,1.4479776E9]|4.976190476190476|
# |[0.0,1.4482476E9]|4.0  |[0.0,1.4482476E9]|4.976190476190476|
# |[0.0,1.4486904E9]|6.0  |[0.0,1.4486904E9]|4.976190476190476|
# |[0.0,1.4491404E9]|4.0  |[0.0,1.4491404E9]|4.271604938271605|
# |[0.0,1.4494356E9]|3.0  |[0.0,1.4494356E9]|4.271604938271605|
# |[0.0,1.4494932E9]|5.0  |[0.0,1.4494932E9]|4.271604938271605|
# |[0.0,1.4505984E9]|3.0  |[0.0,1.4505984E9]|4.271604938271605|
# |[0.0,1.4508612E9]|3.0  |[0.0,1.4508612E9]|4.271604938271605|
# |[0.0,1.4513112E9]|5.0  |[0.0,1.4513112E9]|4.875            |
# |[0.0,1.451574E9] |4.0  |[0.0,1.451574E9] |4.363636363636363|
# |[0.0,1.4516316E9]|4.0  |[0.0,1.4516316E9]|4.363636363636363|
# |[0.0,1.4520816E9]|5.0  |[0.0,1.4520816E9]|4.948717948717949|
# |[0.0,1.4552352E9]|4.0  |[0.0,1.4552352E9]|4.948717948717949|
# |[0.0,1.4554404E9]|6.0  |[0.0,1.4554404E9]|4.948717948717949|
# |[0.0,1.455498E9] |7.0  |[0.0,1.455498E9] |4.948717948717949|
# |[0.0,1.4555304E9]|5.0  |[0.0,1.4555304E9]|4.948717948717949|
# |[0.0,1.459332E9] |2.0  |[0.0,1.459332E9] |4.948717948717949|
# |[0.0,1.459422E9] |4.0  |[0.0,1.459422E9] |3.857142857142857|
# |[0.1,1.4515164E9]|6.0  |[0.1,1.4515164E9]|4.777777777777778|
# |[0.8,1.4489028E9]|5.0  |[0.8,1.4489028E9]|3.0              |
# |[4.9,1.4552604E9]|7.0  |[4.9,1.4552604E9]|3.0              |
# |[5.5,1.4479452E9]|5.0  |[5.5,1.4479452E9]|3.0              |
# |[6.9,1.451754E9] |7.0  |[6.9,1.451754E9] |5.0              |
# |[0.0,1.4474052E9]|3.0  |[0.0,1.4474052E9]|4.976190476190476|
# |[0.0,1.4481828E9]|2.0  |[0.0,1.4481828E9]|4.976190476190476|
# |[0.0,1.448658E9] |8.0  |[0.0,1.448658E9] |4.976190476190476|
# |[0.0,1.4486832E9]|6.0  |[0.0,1.4486832E9]|4.976190476190476|
# |[0.0,1.449486E9] |4.0  |[0.0,1.449486E9] |4.271604938271605|
# |[0.0,1.4506164E9]|4.0  |[0.0,1.4506164E9]|4.271604938271605|
# |[0.0,1.4512968E9]|5.0  |[0.0,1.4512968E9]|4.875            |
# |[0.0,1.4516568E9]|6.0  |[0.0,1.4516568E9]|4.363636363636363|
# |[0.0,1.4552208E9]|2.0  |[0.0,1.4552208E9]|4.948717948717949|
# |[0.0,1.4555484E9]|5.0  |[0.0,1.4555484E9]|4.948717948717949|
# |[0.0,1.4570712E9]|4.0  |[0.0,1.4570712E9]|4.948717948717949|
# |[0.0,1.4593248E9]|2.0  |[0.0,1.4593248E9]|4.948717948717949|
# |[0.1,1.4495436E9]|4.0  |[0.1,1.4495436E9]|4.271604938271605|
# |[0.1,1.4507064E9]|5.0  |[0.1,1.4507064E9]|4.271604938271605|
# |[0.1,1.4507964E9]|5.0  |[0.1,1.4507964E9]|4.271604938271605|
# |[0.1,1.4514768E9]|7.0  |[0.1,1.4514768E9]|4.777777777777778|
# |[0.4,1.4552856E9]|6.0  |[0.4,1.4552856E9]|5.846153846153846|
# |[0.0,1.4478156E9]|3.0  |[0.0,1.4478156E9]|4.976190476190476|
# |[0.0,1.4479056E9]|4.0  |[0.0,1.4479056E9]|4.976190476190476|
# |[0.0,1.4480856E9]|9.0  |[0.0,1.4480856E9]|4.976190476190476|
# |[0.0,1.448676E9] |7.0  |[0.0,1.448676E9] |4.976190476190476|
# |[0.0,1.4487336E9]|6.0  |[0.0,1.4487336E9]|4.976190476190476|
# |[0.0,1.4490612E9]|3.0  |[0.0,1.4490612E9]|3.5              |
# |[0.0,1.4491188E9]|3.0  |[0.0,1.4491188E9]|4.271604938271605|
# |[0.0,1.4491512E9]|5.0  |[0.0,1.4491512E9]|4.271604938271605|
# |[0.0,1.4491836E9]|7.0  |[0.0,1.4491836E9]|4.271604938271605|
# |[0.0,1.4492988E9]|4.0  |[0.0,1.4492988E9]|4.271604938271605|
# |[0.0,1.4494212E9]|3.0  |[0.0,1.4494212E9]|4.271604938271605|
# |[0.0,1.4506668E9]|4.0  |[0.0,1.4506668E9]|4.271604938271605|
# |[0.0,1.4508144E9]|5.0  |[0.0,1.4508144E9]|4.271604938271605|
# |[0.0,1.4509944E9]|2.0  |[0.0,1.4509944E9]|4.271604938271605|
# |[0.0,1.4512068E9]|4.0  |[0.0,1.4512068E9]|4.271604938271605|
# |[0.0,1.4514444E9]|6.0  |[0.0,1.4514444E9]|4.363636363636363|
# |[0.0,1.4515596E9]|4.0  |[0.0,1.4515596E9]|4.363636363636363|
# |[0.0,1.4520672E9]|6.0  |[0.0,1.4520672E9]|4.948717948717949|
# |[0.0,1.4570568E9]|6.0  |[0.0,1.4570568E9]|4.948717948717949|
# |[0.0,1.4571468E9]|8.0  |[0.0,1.4571468E9]|4.948717948717949|
# |[0.1,1.4509692E9]|6.0  |[0.1,1.4509692E9]|4.271604938271605|
# |[1.9,1.455606E9] |3.0  |[1.9,1.455606E9] |5.846153846153846|
# |[0.0,1.447686E9] |4.0  |[0.0,1.447686E9] |4.976190476190476|
# |[0.0,1.4482836E9]|2.0  |[0.0,1.4482836E9]|4.976190476190476|
# |[0.0,1.4486688E9]|6.0  |[0.0,1.4486688E9]|4.976190476190476|
# |[0.0,1.4487588E9]|7.0  |[0.0,1.4487588E9]|4.976190476190476|
# |[0.0,1.448964E9] |3.0  |[0.0,1.448964E9] |3.5              |
# |[0.0,1.4490216E9]|3.0  |[0.0,1.4490216E9]|3.5              |
# |[0.0,1.4490288E9]|3.0  |[0.0,1.4490288E9]|3.5              |
# |[0.0,1.4492916E9]|4.0  |[0.0,1.4492916E9]|4.271604938271605|
# |[0.0,1.4493564E9]|4.0  |[0.0,1.4493564E9]|4.271604938271605|
# |[0.0,1.4495616E9]|3.0  |[0.0,1.4495616E9]|4.271604938271605|
# |[0.0,1.4514048E9]|5.0  |[0.0,1.4514048E9]|4.363636363636363|
# |[0.0,1.4514624E9]|6.0  |[0.0,1.4514624E9]|4.363636363636363|
# |[0.0,1.4555664E9]|3.0  |[0.0,1.4555664E9]|4.948717948717949|
# |[0.0,1.4594004E9]|4.0  |[0.0,1.4594004E9]|3.857142857142857|
# |[0.1,1.4493816E9]|5.0  |[0.1,1.4493816E9]|4.271604938271605|
# |[0.1,1.4509296E9]|5.0  |[0.1,1.4509296E9]|4.271604938271605|
# |[0.1,1.4511672E9]|4.0  |[0.1,1.4511672E9]|4.271604938271605|
# |[0.1,1.4514948E9]|4.0  |[0.1,1.4514948E9]|4.777777777777778|
# |[0.1,1.4551812E9]|4.0  |[0.1,1.4551812E9]|5.846153846153846|
# |[0.5,1.4515848E9]|5.0  |[0.5,1.4515848E9]|4.777777777777778|
# |[0.7,1.4513472E9]|4.0  |[0.7,1.4513472E9]|5.0              |
# |[0.7,1.4517576E9]|7.0  |[0.7,1.4517576E9]|5.846153846153846|
# |[5.7,1.4471208E9]|4.0  |[5.7,1.4471208E9]|5.0              |
# |[0.0,1.4472612E9]|3.0  |[0.0,1.4472612E9]|4.976190476190476|
# |[0.0,1.4479488E9]|6.0  |[0.0,1.4479488E9]|4.976190476190476|
# |[0.0,1.448334E9] |3.0  |[0.0,1.448334E9] |4.976190476190476|
# |[0.0,1.4483664E9]|5.0  |[0.0,1.4483664E9]|4.976190476190476|
# |[0.0,1.4489316E9]|5.0  |[0.0,1.4489316E9]|4.976190476190476|
# |[0.0,1.4489892E9]|2.0  |[0.0,1.4489892E9]|3.5              |
# |[0.0,1.4491044E9]|3.0  |[0.0,1.4491044E9]|3.5              |
# |[0.0,1.449522E9] |4.0  |[0.0,1.449522E9] |4.271604938271605|
# |[0.0,1.4505948E9]|3.0  |[0.0,1.4505948E9]|4.271604938271605|
# |[0.0,1.45071E9]  |5.0  |[0.0,1.45071E9]  |4.271604938271605|
# |[0.0,1.4507748E9]|5.0  |[0.0,1.4507748E9]|4.271604938271605|
# |[0.0,1.4509476E9]|5.0  |[0.0,1.4509476E9]|4.271604938271605|
# |[0.0,1.4511276E9]|4.0  |[0.0,1.4511276E9]|4.271604938271605|
# |[0.0,1.4512176E9]|4.0  |[0.0,1.4512176E9]|4.271604938271605|
# |[0.0,1.4570424E9]|5.0  |[0.0,1.4570424E9]|4.948717948717949|
# |[0.0,1.4571072E9]|5.0  |[0.0,1.4571072E9]|4.948717948717949|
# |[0.0,1.4593932E9]|4.0  |[0.0,1.4593932E9]|3.857142857142857|
# |[3.1,1.4517252E9]|9.0  |[3.1,1.4517252E9]|5.846153846153846|
# |[0.0,1.4475564E9]|5.0  |[0.0,1.4475564E9]|4.976190476190476|
# |[0.0,1.4476716E9]|4.0  |[0.0,1.4476716E9]|4.976190476190476|
# |[0.0,1.4486868E9]|6.0  |[0.0,1.4486868E9]|4.976190476190476|
# |[0.0,1.4489496E9]|4.0  |[0.0,1.4489496E9]|3.5              |
# |[0.0,1.4490144E9]|3.0  |[0.0,1.4490144E9]|3.5              |
# |[0.0,1.449072E9] |4.0  |[0.0,1.449072E9] |3.5              |
# |[0.0,1.4491296E9]|4.0  |[0.0,1.4491296E9]|4.271604938271605|
# |[0.0,1.4492196E9]|4.0  |[0.0,1.4492196E9]|4.271604938271605|
# |[0.0,1.4493096E9]|5.0  |[0.0,1.4493096E9]|4.271604938271605|
# |[0.0,1.4494248E9]|3.0  |[0.0,1.4494248E9]|4.271604938271605|
# |[0.0,1.4495148E9]|5.0  |[0.0,1.4495148E9]|4.271604938271605|
# |[0.0,1.4505876E9]|3.0  |[0.0,1.4505876E9]|4.271604938271605|
# |[0.0,1.4506776E9]|3.0  |[0.0,1.4506776E9]|4.271604938271605|
# |[0.0,1.4507676E9]|4.0  |[0.0,1.4507676E9]|4.271604938271605|
# |[0.0,1.4508828E9]|3.0  |[0.0,1.4508828E9]|4.271604938271605|
# |[0.0,1.4510304E9]|4.0  |[0.0,1.4510304E9]|4.271604938271605|
# |[0.0,1.451538E9] |5.0  |[0.0,1.451538E9] |4.363636363636363|
# |[0.0,1.451628E9] |4.0  |[0.0,1.451628E9] |4.363636363636363|
# |[0.0,1.4554044E9]|7.0  |[0.0,1.4554044E9]|4.948717948717949|
# |[0.0,1.455552E9] |5.0  |[0.0,1.455552E9] |4.948717948717949|
# |[0.0,1.4571E9]   |6.0  |[0.0,1.4571E9]   |4.948717948717949|
# |[0.0,1.4571576E9]|7.0  |[0.0,1.4571576E9]|4.948717948717949|
# |[0.1,1.4489244E9]|5.0  |[0.1,1.4489244E9]|7.0              |
# |[0.1,1.4507352E9]|5.0  |[0.1,1.4507352E9]|4.271604938271605|
# |[0.1,1.4509152E9]|4.0  |[0.1,1.4509152E9]|4.271604938271605|
# |[0.1,1.4513004E9]|5.0  |[0.1,1.4513004E9]|4.875            |
# |[1.5,1.4482116E9]|3.0  |[1.5,1.4482116E9]|3.0              |
# |[3.1,1.4556096E9]|3.0  |[3.1,1.4556096E9]|5.846153846153846|
# |[5.3,1.4521032E9]|4.0  |[5.3,1.4521032E9]|3.0              |
# |[0.0,1.4475492E9]|5.0  |[0.0,1.4475492E9]|4.976190476190476|
# |[0.0,1.4484096E9]|6.0  |[0.0,1.4484096E9]|4.976190476190476|
# |[0.0,1.4487948E9]|7.0  |[0.0,1.4487948E9]|4.976190476190476|
# |[0.0,1.4489424E9]|4.0  |[0.0,1.4489424E9]|3.5              |
# |[0.0,1.4490072E9]|3.0  |[0.0,1.4490072E9]|3.5              |
# |[0.0,1.4493024E9]|4.0  |[0.0,1.4493024E9]|4.271604938271605|
# |[0.0,1.4494176E9]|4.0  |[0.0,1.4494176E9]|4.271604938271605|
# |[0.0,1.4495652E9]|4.0  |[0.0,1.4495652E9]|4.271604938271605|
# |[0.0,1.4507604E9]|5.0  |[0.0,1.4507604E9]|4.271604938271605|
# |[0.0,1.452096E9] |3.0  |[0.0,1.452096E9] |4.948717948717949|
# |[0.0,1.4554224E9]|6.0  |[0.0,1.4554224E9]|4.948717948717949|
# |[0.0,1.4554296E9]|6.0  |[0.0,1.4554296E9]|4.948717948717949|
# |[0.0,1.4555124E9]|5.0  |[0.0,1.4555124E9]|4.948717948717949|
# |[0.0,1.4593464E9]|3.0  |[0.0,1.4593464E9]|3.857142857142857|
# |[0.1,1.4486472E9]|9.0  |[0.1,1.4486472E9]|7.0              |
# |[0.1,1.4488596E9]|5.0  |[0.1,1.4488596E9]|7.0              |
# |[0.1,1.451178E9] |4.0  |[0.1,1.451178E9] |4.271604938271605|
# |[0.1,1.4512608E9]|5.0  |[0.1,1.4512608E9]|4.875            |
# |[0.1,1.4514408E9]|6.0  |[0.1,1.4514408E9]|4.777777777777778|
# |[0.1,1.4514732E9]|6.0  |[0.1,1.4514732E9]|4.777777777777778|
# |[0.1,1.4515308E9]|6.0  |[0.1,1.4515308E9]|4.777777777777778|
# |[0.1,1.4515632E9]|4.0  |[0.1,1.4515632E9]|4.777777777777778|
# |[0.1,1.4553972E9]|5.0  |[0.1,1.4553972E9]|5.846153846153846|
# |[8.6,1.4515884E9]|4.0  |[8.6,1.4515884E9]|5.0              |
# |[0.0,1.447182E9] |2.0  |[0.0,1.447182E9] |3.2              |
# |[0.0,1.4472144E9]|2.0  |[0.0,1.4472144E9]|4.976190476190476|
# |[0.0,1.44882E9]  |6.0  |[0.0,1.44882E9]  |4.976190476190476|
# |[0.0,1.4494752E9]|3.0  |[0.0,1.4494752E9]|4.271604938271605|
# |[0.0,1.4506308E9]|4.0  |[0.0,1.4506308E9]|4.271604938271605|
# |[0.0,1.4506632E9]|3.0  |[0.0,1.4506632E9]|4.271604938271605|
# |[0.0,1.4509908E9]|3.0  |[0.0,1.4509908E9]|4.271604938271605|
# |[0.0,1.4510484E9]|5.0  |[0.0,1.4510484E9]|4.271604938271605|
# |[0.0,1.451106E9] |3.0  |[0.0,1.451106E9] |4.271604938271605|
# |[0.0,1.451556E9] |3.0  |[0.0,1.451556E9] |4.363636363636363|
# |[0.0,1.4516136E9]|3.0  |[0.0,1.4516136E9]|4.363636363636363|
# |[0.0,1.4520312E9]|5.0  |[0.0,1.4520312E9]|4.948717948717949|
# |[0.0,1.45539E9]  |7.0  |[0.0,1.45539E9]  |4.948717948717949|
# |[0.0,1.4555376E9]|6.0  |[0.0,1.4555376E9]|4.948717948717949|
# |[0.0,1.4570856E9]|4.0  |[0.0,1.4570856E9]|4.948717948717949|
# |[0.0,1.459404E9] |5.0  |[0.0,1.459404E9] |3.857142857142857|
# |[0.1,1.4495004E9]|5.0  |[0.1,1.4495004E9]|4.271604938271605|
# |[0.1,1.450926E9] |4.0  |[0.1,1.450926E9] |4.271604938271605|
# |[0.1,1.4514336E9]|6.0  |[0.1,1.4514336E9]|4.777777777777778|
# |[0.1,1.4516712E9]|6.0  |[0.1,1.4516712E9]|5.846153846153846|
# |[0.4,1.4480424E9]|6.0  |[0.4,1.4480424E9]|3.0              |
# |[8.8,1.4507208E9]|4.0  |[8.8,1.4507208E9]|4.271604938271605|
# +-----------------+-----+-----------------+-----------------+

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator = RegressionEvaluator(labelCol="label",
                                predictionCol="prediction",
                                metricName="rmse")

rmse = evaluator.evaluate(predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 1.36246

# %%
treeModel = model.stages[1]
print(treeModel)
# Out:
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4cd38c80fda17e41428a) of depth 5 with 35 nodes
